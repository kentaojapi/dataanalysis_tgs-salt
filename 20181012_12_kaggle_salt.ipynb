# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kentaojapi/dataanalysis_tgs-salt/blob/master/20181012_12_kaggle_salt.ipynb)

# %%
# download API key from google drive
## Original: https://colab.research.google.com/drive/1eufc8aNCdjHbrBhuy7M7X6BGyzAyRbrF#scrollTo=y5_288BYp6H1
## When you run for the first time, you will see a link to authenticate.

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/content/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Download 100%.

# %%
# !ls
# Out:
# adc.json  sample_data

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
# !kaggle competitions download -c tgs-salt-identification-challenge
# !unzip train.zip
# !mv images/ train/
# !unzip test.zip
# !mv images/ test/
# !rm train.zip
# !rm test.zip
# !df -h
from IPython.display import clear_output
clear_output()

# %%
import os
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

# import cv2
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input, Dense, Dropout, BatchNormalization, Activation, Add, multiply, Multiply
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf


from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
ids= ['1f1cc6b3a4','5b7c160d0d','6c40978ddf','7dfdf6eeb8','7e5a6e5013']
plt.figure(figsize=(20,10))
for j, img_name in enumerate(ids):
    q = j+1
    img = load_img('../content/train/' + img_name + '.png')
    img_mask = load_img('../content/masks/' + img_name + '.png')
    
    plt.subplot(1,2*(1+len(ids)),q*2-1)
    plt.imshow(img)
    plt.subplot(1,2*(1+len(ids)),q*2)
    plt.imshow(img_mask)
plt.show()

# %%
# version = 5
# basic_name = f'Unet_resnet_v{version}'
# save_model_name = basic_name + '.model'
# submission_file = basic_name + '.csv'

# print(save_model_name)
# print(submission_file)

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../content/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../content/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("../content/train/{}.png".format(idx), grayscale=True)) / 255 for idx in train_df.index]

# %%
train_df["masks"] = [np.array(load_img("../content/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in train_df.index]

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5,0,'Coverage class')

# %%
#Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5,1,'Depth distribution')

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
        #x = Dropout(0.5)(x) #add
    return x

# def se_block(x, filters):
#     x = AveragePooling2D(pool_size=(FIELD_SIZE, FIELD_SIZE))(x)
#     x = Conv2D(filters, (1, 1))(x)
#     x = Activation("relu")(x)
#     x = Conv2D(128, (1, 1))(x)
#     x = Activation("sigmoid")(x)
#     x = UpSampling2D(size=(FIELD_SIZE, FIELD_SIZE))(x)
#     x = 
#     return x
    
# def se_block(input_tensor, compress_rate = 16):
#     num_channels = int(input_tensor.shape[-1]) # Tensorflow backend
#     bottle_neck = int(num_channels//compress_rate)
#     se_branch = GlobalAveragePooling2D()(input_tensor)
#     se_branch = Dense(bottle_neck, activation='relu')(se_branch)
#     se_branch = Dense(num_channels, activation='sigmoid')(se_branch)
#     x = input_tensor 
#     out = multiply([x, se_branch])
#     return out

def cse_block(prevlayer):
    mean = Lambda(lambda xin: K.mean(xin, axis=[1, 2]))(prevlayer)
    lin1 = Dense(K.int_shape(prevlayer)[3]//2, activation='relu')(mean)
    lin2 = Dense(K.int_shape(prevlayer)[3], activation='sigmoid')(lin1)
    x = Multiply()([prevlayer, lin2])
    return x

def sse_block(prevlayer):
    conv = Conv2D(1, (1, 1), padding="same", kernel_initializer="he_normal", 
                  activation='sigmoid', strides=(1, 1))(prevlayer)
    conv = multiply([prevlayer, conv])
    return conv

def csse_block(x):
    '''
    Implementation of Concurrent Spatial and Channel ‘Squeeze & Excitation’ in Fully Convolutional Networks
    https://arxiv.org/abs/1803.02579
    '''
    cse = cse_block(x)
    sse = sse_block(x)
    x = Add()([cse, sse])
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    #x = se_block(x)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1, start_neurons * 1)
    conv1 = residual_block(conv1, start_neurons * 1, True)
    conv1 = csse_block(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    conv2 = csse_block(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)
    
    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    conv3 = csse_block(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    conv4 = csse_block(conv4)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)
                                  
    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    uconv4 = csse_block(uconv4)


    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    uconv3 = csse_block(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)
    uconv3 = csse_block(uconv3)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    uconv4 = csse_block(uconv4)
                                  
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    uconv1 = csse_block(uconv1)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
#             metric.append(1)
#             continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        #loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16, 0.5)

model1 = Model(input_layer, output_layer)

#c = optimizers.adam(lr = 0.01)
c = optimizers.Nadam(lr=0.002)
#c = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

model1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 101, 101, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 101, 101, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 101, 101, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 101, 101, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 101, 101, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 101, 101, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 101, 101, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 101, 101, 16) 0           conv2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 101, 101, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 101, 101, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 101, 101, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 101, 101, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 101, 101, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 101, 101, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 101, 101, 16) 0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16)           0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            136         lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           144         dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 101, 101, 1)  17          activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 101, 101, 16) 0           activation_5[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 101, 101, 16) 0           activation_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 101, 101, 16) 0           multiply_1[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50, 50, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 32)   0           conv2d_9[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 50, 50, 32)   0           conv2d_11[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 32)   128         add_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32)           0           activation_10[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           528         lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           544         dense_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 50, 50, 1)    33          activation_10[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 50, 50, 32)   0           activation_10[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 50, 50, 32)   0           activation_10[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 50, 50, 32)   0           multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 25, 25, 64)   0           conv2d_15[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         add_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 25, 25, 64)   0           conv2d_17[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64)           0           activation_15[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           2080        lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           2112        dense_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 1)    65          activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 25, 25, 64)   0           activation_15[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 25, 25, 64)   0           activation_15[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 25, 25, 64)   0           multiply_5[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 12, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 12, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 12, 12, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 128)  0           conv2d_21[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 12, 128)  512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 12, 12, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 12, 12, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 128)  0           conv2d_23[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128)          0           activation_20[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        lambda_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          8320        dense_7[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 12, 12, 1)    129         activation_20[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 12, 12, 128)  0           activation_20[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 12, 12, 128)  0           activation_20[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 128)  0           multiply_7[0][0]
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 128)    0           add_12[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 6, 6, 128)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 6, 6, 256)    295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 256)    1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 6, 6, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 256)    1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 6, 6, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 6, 256)    0           conv2d_27[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 256)    1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 6, 6, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 6, 6, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 6, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 6, 6, 256)    590080      activation_24[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 6, 6, 256)    0           conv2d_29[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 6, 6, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 12, 12, 128)  295040      activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_1[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 12, 12, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  147584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 12, 12, 128)  0           conv2d_32[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 12, 128)  512         add_15[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 128)  147584      activation_29[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 12, 12, 128)  0           conv2d_34[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 128)  512         add_16[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 128)          0           activation_30[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           8256        lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          8320        dense_9[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 1)    129         activation_30[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 12, 12, 128)  0           activation_30[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 12, 12, 128)  0           activation_30[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 12, 12, 128)  0           multiply_9[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 25, 25, 64)   73792       add_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_2[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25, 25, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 128)          0           dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 64)           8256        lambda_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          8320        dense_11[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 25, 25, 1)    129         dropout_6[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 25, 25, 128)  0           dropout_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 25, 25, 128)  0           dropout_6[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 25, 25, 128)  0           multiply_11[0][0]
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 25, 25, 64)   73792       add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 25, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 25, 25, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 25, 25, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 25, 25, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 25, 25, 64)   0           conv2d_39[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 64)   256         add_19[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 25, 25, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 25, 25, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 25, 25, 64)   0           conv2d_41[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   256         add_20[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 64)           0           activation_35[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 32)           2080        lambda_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 64)           2112        dense_13[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 25, 25, 1)    65          activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 25, 25, 64)   0           activation_35[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 25, 25, 64)   0           activation_35[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 25, 25, 64)   0           multiply_13[0][0]
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 50, 50, 32)   18464       add_21[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 64)   0           conv2d_transpose_3[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 50, 50, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 50, 50, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 32)   128         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 50, 50, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 32)   128         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 50, 50, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 50, 50, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 50, 50, 32)   0           conv2d_45[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 32)   128         add_22[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 50, 50, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 50, 50, 32)   9248        activation_39[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 50, 50, 32)   0           conv2d_47[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 32)   128         add_23[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 101, 101, 16) 4624        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 101, 101, 32) 0           conv2d_transpose_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 101, 101, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 101, 101, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 101, 101, 16) 64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 101, 101, 16) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 101, 101, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 101, 101, 16) 64          conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 101, 101, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 101, 101, 16) 2320        activation_42[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 101, 101, 16) 0           conv2d_51[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 101, 101, 16) 64          add_25[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 101, 101, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 101, 101, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 101, 101, 16) 64          conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 101, 101, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 101, 101, 16) 2320        activation_44[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 101, 101, 16) 0           conv2d_53[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 101, 101, 16) 64          add_26[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 101, 101, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16)           0           activation_45[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 8)            136         lambda_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 16)           144         dense_17[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 101, 101, 1)  17          activation_45[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 101, 101, 16) 0           activation_45[0][0]
#                                                                  dense_18[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 101, 101, 16) 0           activation_45[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 101, 101, 16) 0           multiply_17[0][0]
#                                                                  multiply_18[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 101, 101, 1)  17          add_27[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 101, 101, 1)  0           conv2d_55[0][0]
# ==================================================================================================
# Total params: 5,180,185
# Trainable params: 5,172,825
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
class ModelSave(ModelCheckpoint):
    def __init__(self, filepath, verbose=0, save_freq=25):
        super(ModelSave, self).__init__(filepath, verbose=verbose)
        self.save_freq = save_freq

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.save_freq == 0:
            times = epoch / self.save_freq 
            model1.save("drive/My Drive/kaggle/{0}times-{1}".format(times, self.filepath))

# %%
#1st-25epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '24th-2-model1-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)
save_model =ModelSave(filepath=save_file)

epochs = 100
#epochs = 25
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr, save_model], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/100
#  - 127s - loss: 0.3916 - my_iou_metric: 0.4205 - val_loss: 0.3520 - val_my_iou_metric: 0.4913
#
# Epoch 00001: my_iou_metric improved from -inf to 0.42055, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 2/100
#  - 108s - loss: 0.2913 - my_iou_metric: 0.5380 - val_loss: 0.2796 - val_my_iou_metric: 0.5496
#
# Epoch 00002: my_iou_metric improved from 0.42055 to 0.53797, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 3/100
#  - 108s - loss: 0.2750 - my_iou_metric: 0.5371 - val_loss: 1.0776 - val_my_iou_metric: 0.3310
#
# Epoch 00003: my_iou_metric did not improve from 0.53797
# Epoch 4/100
#  - 108s - loss: 0.2451 - my_iou_metric: 0.5576 - val_loss: 0.6513 - val_my_iou_metric: 0.4090
#
# Epoch 00004: my_iou_metric improved from 0.53797 to 0.55758, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 5/100
#  - 108s - loss: 0.2259 - my_iou_metric: 0.5685 - val_loss: 0.5731 - val_my_iou_metric: 0.4283
#
# Epoch 00005: my_iou_metric improved from 0.55758 to 0.56852, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 6/100
#  - 108s - loss: 0.2198 - my_iou_metric: 0.5701 - val_loss: 0.2123 - val_my_iou_metric: 0.6417
#
# Epoch 00006: my_iou_metric improved from 0.56852 to 0.57014, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 7/100
#  - 107s - loss: 0.2073 - my_iou_metric: 0.5937 - val_loss: 0.8266 - val_my_iou_metric: 0.4080
#
# Epoch 00007: my_iou_metric improved from 0.57014 to 0.59373, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 8/100
#  - 108s - loss: 0.1974 - my_iou_metric: 0.6203 - val_loss: 0.7766 - val_my_iou_metric: 0.4345
#
# Epoch 00008: my_iou_metric improved from 0.59373 to 0.62031, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 9/100
#  - 108s - loss: 0.1874 - my_iou_metric: 0.6321 - val_loss: 0.2512 - val_my_iou_metric: 0.6110
#
# Epoch 00009: my_iou_metric improved from 0.62031 to 0.63209, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 10/100
#  - 108s - loss: 0.1835 - my_iou_metric: 0.6460 - val_loss: 0.3244 - val_my_iou_metric: 0.5679
#
# Epoch 00010: my_iou_metric improved from 0.63209 to 0.64602, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 11/100
#  - 108s - loss: 0.1700 - my_iou_metric: 0.6683 - val_loss: 0.1705 - val_my_iou_metric: 0.7065
#
# Epoch 00011: my_iou_metric improved from 0.64602 to 0.66828, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 12/100
#  - 108s - loss: 0.1757 - my_iou_metric: 0.6525 - val_loss: 0.1791 - val_my_iou_metric: 0.6913
#
# Epoch 00012: my_iou_metric did not improve from 0.66828
# Epoch 13/100
#  - 107s - loss: 0.1641 - my_iou_metric: 0.6694 - val_loss: 0.6383 - val_my_iou_metric: 0.4180
#
# Epoch 00013: my_iou_metric improved from 0.66828 to 0.66942, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 14/100
#  - 108s - loss: 0.1611 - my_iou_metric: 0.6769 - val_loss: 0.3876 - val_my_iou_metric: 0.5022
#
# Epoch 00014: my_iou_metric improved from 0.66942 to 0.67686, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 15/100
#  - 108s - loss: 0.1564 - my_iou_metric: 0.6802 - val_loss: 0.1878 - val_my_iou_metric: 0.6879
#
# Epoch 00015: my_iou_metric improved from 0.67686 to 0.68016, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 16/100
#  - 107s - loss: 0.1673 - my_iou_metric: 0.6692 - val_loss: 0.3112 - val_my_iou_metric: 0.5780
#
# Epoch 00016: my_iou_metric did not improve from 0.68016
# Epoch 17/100
#  - 107s - loss: 0.1620 - my_iou_metric: 0.6798 - val_loss: 0.1900 - val_my_iou_metric: 0.6994
#
# Epoch 00017: my_iou_metric did not improve from 0.68016
# Epoch 18/100
#  - 108s - loss: 0.1468 - my_iou_metric: 0.6976 - val_loss: 0.1586 - val_my_iou_metric: 0.7120
#
# Epoch 00018: my_iou_metric improved from 0.68016 to 0.69762, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 19/100
#  - 107s - loss: 0.1457 - my_iou_metric: 0.7022 - val_loss: 0.1819 - val_my_iou_metric: 0.7060
#
# Epoch 00019: my_iou_metric improved from 0.69762 to 0.70216, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 20/100
#  - 108s - loss: 0.1371 - my_iou_metric: 0.7043 - val_loss: 0.1990 - val_my_iou_metric: 0.6843
#
# Epoch 00020: my_iou_metric improved from 0.70216 to 0.70433, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 21/100
#  - 107s - loss: 0.1359 - my_iou_metric: 0.7218 - val_loss: 0.1890 - val_my_iou_metric: 0.7055
#
# Epoch 00021: my_iou_metric improved from 0.70433 to 0.72175, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 22/100
#  - 108s - loss: 0.1356 - my_iou_metric: 0.7180 - val_loss: 0.1527 - val_my_iou_metric: 0.7300
#
# Epoch 00022: my_iou_metric did not improve from 0.72175
# Epoch 23/100
#  - 108s - loss: 0.1336 - my_iou_metric: 0.7201 - val_loss: 0.1718 - val_my_iou_metric: 0.7225
#
# Epoch 00023: my_iou_metric did not improve from 0.72175
# Epoch 24/100
#  - 107s - loss: 0.1380 - my_iou_metric: 0.7162 - val_loss: 0.1641 - val_my_iou_metric: 0.7149
#
# Epoch 00024: my_iou_metric did not improve from 0.72175
# Epoch 25/100
#  - 107s - loss: 0.1251 - my_iou_metric: 0.7296 - val_loss: 0.1613 - val_my_iou_metric: 0.7269
#
# Epoch 00025: my_iou_metric improved from 0.72175 to 0.72958, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 26/100
#  - 108s - loss: 0.1312 - my_iou_metric: 0.7278 - val_loss: 0.1483 - val_my_iou_metric: 0.7279
#
# Epoch 00026: my_iou_metric did not improve from 0.72958
# Epoch 27/100
#  - 107s - loss: 0.1228 - my_iou_metric: 0.7388 - val_loss: 0.1661 - val_my_iou_metric: 0.6925
#
# Epoch 00027: my_iou_metric improved from 0.72958 to 0.73883, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 28/100
#  - 108s - loss: 0.1206 - my_iou_metric: 0.7352 - val_loss: 0.1640 - val_my_iou_metric: 0.7125
#
# Epoch 00028: my_iou_metric did not improve from 0.73883
# Epoch 29/100
#  - 108s - loss: 0.1192 - my_iou_metric: 0.7418 - val_loss: 0.1392 - val_my_iou_metric: 0.7321
#
# Epoch 00029: my_iou_metric improved from 0.73883 to 0.74175, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 30/100
#  - 107s - loss: 0.1171 - my_iou_metric: 0.7452 - val_loss: 0.1408 - val_my_iou_metric: 0.7384
#
# Epoch 00030: my_iou_metric improved from 0.74175 to 0.74520, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 31/100
#  - 108s - loss: 0.1147 - my_iou_metric: 0.7513 - val_loss: 0.1390 - val_my_iou_metric: 0.7455
#
# Epoch 00031: my_iou_metric improved from 0.74520 to 0.75127, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 32/100
#  - 108s - loss: 0.1155 - my_iou_metric: 0.7391 - val_loss: 0.1386 - val_my_iou_metric: 0.7399
#
# Epoch 00032: my_iou_metric did not improve from 0.75127
# Epoch 33/100
#  - 107s - loss: 0.1252 - my_iou_metric: 0.7333 - val_loss: 0.1558 - val_my_iou_metric: 0.7264
#
# Epoch 00033: my_iou_metric did not improve from 0.75127
# Epoch 34/100
#  - 108s - loss: 0.1177 - my_iou_metric: 0.7434 - val_loss: 0.1419 - val_my_iou_metric: 0.7560
#
# Epoch 00034: my_iou_metric did not improve from 0.75127
# Epoch 35/100
#  - 107s - loss: 0.1133 - my_iou_metric: 0.7476 - val_loss: 0.1369 - val_my_iou_metric: 0.7379
#
# Epoch 00035: my_iou_metric did not improve from 0.75127
# Epoch 36/100
#  - 107s - loss: 0.1130 - my_iou_metric: 0.7469 - val_loss: 0.1510 - val_my_iou_metric: 0.7427
#
# Epoch 00036: my_iou_metric did not improve from 0.75127
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 37/100
#  - 107s - loss: 0.1026 - my_iou_metric: 0.7610 - val_loss: 0.1316 - val_my_iou_metric: 0.7766
#
# Epoch 00037: my_iou_metric improved from 0.75127 to 0.76102, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 38/100
#  - 107s - loss: 0.0979 - my_iou_metric: 0.7654 - val_loss: 0.1421 - val_my_iou_metric: 0.7614
#
# Epoch 00038: my_iou_metric improved from 0.76102 to 0.76539, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 39/100
#  - 107s - loss: 0.0992 - my_iou_metric: 0.7698 - val_loss: 0.1395 - val_my_iou_metric: 0.7539
#
# Epoch 00039: my_iou_metric improved from 0.76539 to 0.76983, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 40/100
#  - 107s - loss: 0.0958 - my_iou_metric: 0.7748 - val_loss: 0.1335 - val_my_iou_metric: 0.7601
#
# Epoch 00040: my_iou_metric improved from 0.76983 to 0.77481, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 41/100
#  - 107s - loss: 0.0942 - my_iou_metric: 0.7697 - val_loss: 0.1370 - val_my_iou_metric: 0.7666
#
# Epoch 00041: my_iou_metric did not improve from 0.77481
# Epoch 42/100
#  - 107s - loss: 0.0932 - my_iou_metric: 0.7762 - val_loss: 0.1359 - val_my_iou_metric: 0.7700
#
# Epoch 00042: my_iou_metric improved from 0.77481 to 0.77623, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 43/100
#  - 107s - loss: 0.0910 - my_iou_metric: 0.7748 - val_loss: 0.1246 - val_my_iou_metric: 0.7740
#
# Epoch 00043: my_iou_metric did not improve from 0.77623
# Epoch 44/100
#  - 107s - loss: 0.0911 - my_iou_metric: 0.7772 - val_loss: 0.1337 - val_my_iou_metric: 0.7740
#
# Epoch 00044: my_iou_metric improved from 0.77623 to 0.77720, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 45/100
#  - 107s - loss: 0.0983 - my_iou_metric: 0.7692 - val_loss: 0.1318 - val_my_iou_metric: 0.7699
#
# Epoch 00045: my_iou_metric did not improve from 0.77720
# Epoch 46/100
#  - 107s - loss: 0.0875 - my_iou_metric: 0.7836 - val_loss: 0.1274 - val_my_iou_metric: 0.7680
#
# Epoch 00046: my_iou_metric improved from 0.77720 to 0.78356, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 47/100
#  - 107s - loss: 0.0911 - my_iou_metric: 0.7791 - val_loss: 0.1310 - val_my_iou_metric: 0.7666
#
# Epoch 00047: my_iou_metric did not improve from 0.78356
# Epoch 48/100
#  - 107s - loss: 0.0847 - my_iou_metric: 0.7864 - val_loss: 0.1234 - val_my_iou_metric: 0.7740
#
# Epoch 00048: my_iou_metric improved from 0.78356 to 0.78636, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 49/100
#  - 107s - loss: 0.0864 - my_iou_metric: 0.7829 - val_loss: 0.1211 - val_my_iou_metric: 0.7717
#
# Epoch 00049: my_iou_metric did not improve from 0.78636
# Epoch 50/100
#  - 107s - loss: 0.0860 - my_iou_metric: 0.7806 - val_loss: 0.1440 - val_my_iou_metric: 0.7720
#
# Epoch 00050: my_iou_metric did not improve from 0.78636
# Epoch 51/100
#  - 107s - loss: 0.0871 - my_iou_metric: 0.7817 - val_loss: 0.1427 - val_my_iou_metric: 0.7601
#
# Epoch 00051: my_iou_metric did not improve from 0.78636
# Epoch 52/100
#  - 107s - loss: 0.0866 - my_iou_metric: 0.7843 - val_loss: 0.1528 - val_my_iou_metric: 0.7687
#
# Epoch 00052: my_iou_metric did not improve from 0.78636
# Epoch 53/100
#  - 107s - loss: 0.0869 - my_iou_metric: 0.7821 - val_loss: 0.1374 - val_my_iou_metric: 0.7650
#
# Epoch 00053: my_iou_metric did not improve from 0.78636
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 54/100
#  - 107s - loss: 0.0764 - my_iou_metric: 0.7962 - val_loss: 0.1514 - val_my_iou_metric: 0.7654
#
# Epoch 00054: my_iou_metric improved from 0.78636 to 0.79620, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 55/100
#  - 107s - loss: 0.0744 - my_iou_metric: 0.7998 - val_loss: 0.1504 - val_my_iou_metric: 0.7762
#
# Epoch 00055: my_iou_metric improved from 0.79620 to 0.79981, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 56/100
#  - 107s - loss: 0.0728 - my_iou_metric: 0.8010 - val_loss: 0.1237 - val_my_iou_metric: 0.7925
#
# Epoch 00056: my_iou_metric improved from 0.79981 to 0.80095, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 57/100
#  - 107s - loss: 0.0736 - my_iou_metric: 0.8018 - val_loss: 0.1648 - val_my_iou_metric: 0.7656
#
# Epoch 00057: my_iou_metric improved from 0.80095 to 0.80178, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 58/100
#  - 107s - loss: 0.0721 - my_iou_metric: 0.7990 - val_loss: 0.1402 - val_my_iou_metric: 0.7869
#
# Epoch 00058: my_iou_metric did not improve from 0.80178
# Epoch 59/100
#  - 107s - loss: 0.0754 - my_iou_metric: 0.7970 - val_loss: 0.1209 - val_my_iou_metric: 0.7805
#
# Epoch 00059: my_iou_metric did not improve from 0.80178
# Epoch 60/100
#  - 107s - loss: 0.0732 - my_iou_metric: 0.8013 - val_loss: 0.1241 - val_my_iou_metric: 0.7932
#
# Epoch 00060: my_iou_metric did not improve from 0.80178
# Epoch 61/100
#  - 107s - loss: 0.0700 - my_iou_metric: 0.8003 - val_loss: 0.1535 - val_my_iou_metric: 0.7777
#
# Epoch 00061: my_iou_metric did not improve from 0.80178
# Epoch 62/100
#  - 107s - loss: 0.0721 - my_iou_metric: 0.8015 - val_loss: 0.1246 - val_my_iou_metric: 0.7785
#
# Epoch 00062: my_iou_metric did not improve from 0.80178
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 63/100
#  - 107s - loss: 0.0687 - my_iou_metric: 0.8075 - val_loss: 0.1256 - val_my_iou_metric: 0.7885
#
# Epoch 00063: my_iou_metric improved from 0.80178 to 0.80752, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 64/100
#  - 107s - loss: 0.0655 - my_iou_metric: 0.8069 - val_loss: 0.1479 - val_my_iou_metric: 0.7745
#
# Epoch 00064: my_iou_metric did not improve from 0.80752
# Epoch 65/100
#  - 107s - loss: 0.0631 - my_iou_metric: 0.8095 - val_loss: 0.1387 - val_my_iou_metric: 0.7861
#
# Epoch 00065: my_iou_metric improved from 0.80752 to 0.80950, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 66/100
#  - 107s - loss: 0.0658 - my_iou_metric: 0.8071 - val_loss: 0.1307 - val_my_iou_metric: 0.7909
#
# Epoch 00066: my_iou_metric did not improve from 0.80950
# Epoch 67/100
#  - 107s - loss: 0.0637 - my_iou_metric: 0.8082 - val_loss: 0.1316 - val_my_iou_metric: 0.7906
#
# Epoch 00067: my_iou_metric did not improve from 0.80950
# Epoch 68/100
#  - 107s - loss: 0.0633 - my_iou_metric: 0.8056 - val_loss: 0.1355 - val_my_iou_metric: 0.7924
#
# Epoch 00068: my_iou_metric did not improve from 0.80950
# Epoch 69/100
#  - 107s - loss: 0.0624 - my_iou_metric: 0.8098 - val_loss: 0.1419 - val_my_iou_metric: 0.7815
#
# Epoch 00069: my_iou_metric improved from 0.80950 to 0.80981, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 70/100
#  - 107s - loss: 0.0623 - my_iou_metric: 0.8097 - val_loss: 0.1495 - val_my_iou_metric: 0.7856
#
# Epoch 00070: my_iou_metric did not improve from 0.80981
# Epoch 71/100
#  - 107s - loss: 0.0621 - my_iou_metric: 0.8089 - val_loss: 0.1463 - val_my_iou_metric: 0.7815
#
# Epoch 00071: my_iou_metric did not improve from 0.80981
# Epoch 72/100
#  - 107s - loss: 0.0623 - my_iou_metric: 0.8086 - val_loss: 0.1459 - val_my_iou_metric: 0.7837
#
# Epoch 00072: my_iou_metric did not improve from 0.80981
# Epoch 73/100
#  - 107s - loss: 0.0631 - my_iou_metric: 0.8101 - val_loss: 0.1439 - val_my_iou_metric: 0.7884
#
# Epoch 00073: my_iou_metric improved from 0.80981 to 0.81014, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 74/100
#  - 107s - loss: 0.0624 - my_iou_metric: 0.8104 - val_loss: 0.1414 - val_my_iou_metric: 0.7890
#
# Epoch 00074: my_iou_metric improved from 0.81014 to 0.81038, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 75/100
#  - 107s - loss: 0.0605 - my_iou_metric: 0.8102 - val_loss: 0.1477 - val_my_iou_metric: 0.7894
#
# Epoch 00075: my_iou_metric did not improve from 0.81038
# Epoch 76/100
#  - 107s - loss: 0.0612 - my_iou_metric: 0.8137 - val_loss: 0.1369 - val_my_iou_metric: 0.7906
#
# Epoch 00076: my_iou_metric improved from 0.81038 to 0.81366, saving model to 24th-2-model1-tgs-salt-20181013181030.h5
# Epoch 77/100

# %%
  #1st-25epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '4.0-24th-model1-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '3.0times-24th-2-model1-tgs-salt-20181013181030.h5'
model1 = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric': my_iou_metric})

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

#epochs = 100
epochs = 25
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 119s - loss: 0.0597 - my_iou_metric: 0.8149 - val_loss: 0.1392 - val_my_iou_metric: 0.7940
#
# Epoch 00001: my_iou_metric improved from -inf to 0.81492, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 2/25
#  - 105s - loss: 0.0592 - my_iou_metric: 0.8138 - val_loss: 0.1465 - val_my_iou_metric: 0.7898
#
# Epoch 00002: my_iou_metric did not improve from 0.81492
# Epoch 3/25
#  - 105s - loss: 0.0605 - my_iou_metric: 0.8121 - val_loss: 0.1494 - val_my_iou_metric: 0.7757
#
# Epoch 00003: my_iou_metric did not improve from 0.81492
# Epoch 4/25
#  - 105s - loss: 0.0597 - my_iou_metric: 0.8107 - val_loss: 0.1372 - val_my_iou_metric: 0.7835
#
# Epoch 00004: my_iou_metric did not improve from 0.81492
# Epoch 5/25
#  - 105s - loss: 0.0601 - my_iou_metric: 0.8100 - val_loss: 0.1434 - val_my_iou_metric: 0.7881
#
# Epoch 00005: my_iou_metric did not improve from 0.81492
# Epoch 6/25
#  - 105s - loss: 0.0610 - my_iou_metric: 0.8091 - val_loss: 0.1562 - val_my_iou_metric: 0.7925
#
# Epoch 00006: my_iou_metric did not improve from 0.81492
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 7/25
#  - 105s - loss: 0.0568 - my_iou_metric: 0.8152 - val_loss: 0.1527 - val_my_iou_metric: 0.7940
#
# Epoch 00007: my_iou_metric improved from 0.81492 to 0.81523, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 8/25
#  - 105s - loss: 0.0581 - my_iou_metric: 0.8122 - val_loss: 0.1589 - val_my_iou_metric: 0.7861
#
# Epoch 00008: my_iou_metric did not improve from 0.81523
# Epoch 9/25
#  - 105s - loss: 0.0572 - my_iou_metric: 0.8164 - val_loss: 0.1481 - val_my_iou_metric: 0.7949
#
# Epoch 00009: my_iou_metric improved from 0.81523 to 0.81642, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 10/25
#  - 105s - loss: 0.0564 - my_iou_metric: 0.8178 - val_loss: 0.1558 - val_my_iou_metric: 0.7886
#
# Epoch 00010: my_iou_metric improved from 0.81642 to 0.81784, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 11/25
#  - 105s - loss: 0.0552 - my_iou_metric: 0.8157 - val_loss: 0.1584 - val_my_iou_metric: 0.7965
#
# Epoch 00011: my_iou_metric did not improve from 0.81784
# Epoch 12/25
#  - 105s - loss: 0.0546 - my_iou_metric: 0.8186 - val_loss: 0.1537 - val_my_iou_metric: 0.7955
#
# Epoch 00012: my_iou_metric improved from 0.81784 to 0.81858, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 13/25
#  - 105s - loss: 0.0552 - my_iou_metric: 0.8167 - val_loss: 0.1575 - val_my_iou_metric: 0.7872
#
# Epoch 00013: my_iou_metric did not improve from 0.81858
# Epoch 14/25
#  - 105s - loss: 0.0548 - my_iou_metric: 0.8191 - val_loss: 0.1643 - val_my_iou_metric: 0.7920
#
# Epoch 00014: my_iou_metric improved from 0.81858 to 0.81914, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 15/25
#  - 105s - loss: 0.0539 - my_iou_metric: 0.8183 - val_loss: 0.1660 - val_my_iou_metric: 0.7875
#
# Epoch 00015: my_iou_metric did not improve from 0.81914
# Epoch 16/25
#  - 105s - loss: 0.0555 - my_iou_metric: 0.8179 - val_loss: 0.1602 - val_my_iou_metric: 0.7925
#
# Epoch 00016: my_iou_metric did not improve from 0.81914
# Epoch 17/25
#  - 105s - loss: 0.0543 - my_iou_metric: 0.8173 - val_loss: 0.1630 - val_my_iou_metric: 0.7889
#
# Epoch 00017: my_iou_metric did not improve from 0.81914
# Epoch 18/25
#  - 105s - loss: 0.0546 - my_iou_metric: 0.8187 - val_loss: 0.1562 - val_my_iou_metric: 0.7900
#
# Epoch 00018: my_iou_metric did not improve from 0.81914
# Epoch 19/25
#  - 105s - loss: 0.0536 - my_iou_metric: 0.8184 - val_loss: 0.1663 - val_my_iou_metric: 0.7839
#
# Epoch 00019: my_iou_metric did not improve from 0.81914
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 20/25
#  - 105s - loss: 0.0548 - my_iou_metric: 0.8194 - val_loss: 0.1501 - val_my_iou_metric: 0.7927
#
# Epoch 00020: my_iou_metric improved from 0.81914 to 0.81936, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 21/25
#  - 105s - loss: 0.0532 - my_iou_metric: 0.8192 - val_loss: 0.1616 - val_my_iou_metric: 0.7901
#
# Epoch 00021: my_iou_metric did not improve from 0.81936
# Epoch 22/25
#  - 105s - loss: 0.0512 - my_iou_metric: 0.8218 - val_loss: 0.1622 - val_my_iou_metric: 0.7961
#
# Epoch 00022: my_iou_metric improved from 0.81936 to 0.82177, saving model to 4.0-24th-model1-tgs-salt-20181013231008.h5
# Epoch 23/25
#  - 105s - loss: 0.0518 - my_iou_metric: 0.8193 - val_loss: 0.1507 - val_my_iou_metric: 0.7925
#
# Epoch 00023: my_iou_metric did not improve from 0.82177
# Epoch 24/25
#  - 105s - loss: 0.0523 - my_iou_metric: 0.8159 - val_loss: 0.1544 - val_my_iou_metric: 0.7930
#
# Epoch 00024: my_iou_metric did not improve from 0.82177
# Epoch 25/25
#  - 105s - loss: 0.0494 - my_iou_metric: 0.8205 - val_loss: 0.1656 - val_my_iou_metric: 0.7945
#
# Epoch 00025: my_iou_metric did not improve from 0.82177

# %%
# 1st-50epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '19th-model1-50epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '14th-50epochs-model1-tgs-salt-20181011031055.h5'
model1 = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric': my_iou_metric})

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))

# %%
# 1st-75epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '15th-model1-75epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))

# %%
# 1st-100epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '15th-model1-100epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))

# %%
# 1st-125epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model1-125epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '15th-model1-100epochs-tgs-salt-20181011071012.h5'
model1 = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric': my_iou_metric})


early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))

# %%
from google.colab import drive
drive.mount('/content/drive')
file_name = '20th-25epochs-model1-tgs-salt-20181012121058.h5'
model1 = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric': my_iou_metric})

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric"], label="Validation score")
ax_score.legend()

# %%
# 2nd
from google.colab import drive
drive.mount('/content/drive')
#file_name =  '3.0times-20th-25epochs-model1-tgs-salt-20181013081000.h5'

#model1 = load_model('drive/My Drive/kaggle/{}'.format(file_name), custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
#c = optimizers.adam(lr = 0.01)
c = optimizers.Nadam(lr=0.002)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

model.summary()
# Out:
# Mounted at /content/drive
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 101, 101, 16) 160         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 101, 101, 16) 64          conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 101, 101, 16) 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 101, 101, 16) 2320        activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 101, 101, 16) 64          conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 101, 101, 16) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 101, 101, 16) 2320        activation_96[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 101, 101, 16) 0           conv2d_134[0][0]
#                                                                  conv2d_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 101, 101, 16) 64          add_73[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 101, 101, 16) 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 101, 101, 16) 2320        activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 101, 101, 16) 64          conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 101, 101, 16) 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 101, 101, 16) 2320        activation_98[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 101, 101, 16) 0           conv2d_136[0][0]
#                                                                  add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 101, 101, 16) 64          add_74[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 101, 101, 16) 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 16)           0           activation_99[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 8)            136         lambda_38[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 16)           144         dense_75[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 101, 101, 1)  17          activation_99[0][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 101, 101, 16) 0           activation_99[0][0]
#                                                                  dense_76[0][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 101, 101, 16) 0           activation_99[0][0]
#                                                                  conv2d_137[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 101, 101, 16) 0           multiply_73[0][0]
#                                                                  multiply_74[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 50, 50, 16)   0           add_75[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 50, 50, 16)   0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 50, 50, 32)   4640        dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 50, 50, 32)   128         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 50, 50, 32)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 50, 50, 32)   9248        activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 50, 50, 32)   128         conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 50, 50, 32)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 50, 50, 32)   9248        activation_101[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 50, 50, 32)   0           conv2d_140[0][0]
#                                                                  conv2d_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 50, 50, 32)   128         add_76[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 50, 50, 32)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 50, 50, 32)   9248        activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 50, 50, 32)   128         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 50, 50, 32)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 50, 50, 32)   9248        activation_103[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 50, 50, 32)   0           conv2d_142[0][0]
#                                                                  add_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 50, 50, 32)   128         add_77[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 50, 50, 32)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 32)           0           activation_104[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 16)           528         lambda_39[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 32)           544         dense_77[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 50, 50, 1)    33          activation_104[0][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 50, 50, 32)   0           activation_104[0][0]
#                                                                  dense_78[0][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 50, 50, 32)   0           activation_104[0][0]
#                                                                  conv2d_143[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 50, 50, 32)   0           multiply_75[0][0]
#                                                                  multiply_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 25, 25, 32)   0           add_78[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 25, 25, 32)   0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 25, 25, 64)   18496       dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 25, 25, 64)   256         conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 25, 25, 64)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 25, 25, 64)   36928       activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 25, 25, 64)   256         conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 25, 25, 64)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 25, 25, 64)   36928       activation_106[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 25, 25, 64)   0           conv2d_146[0][0]
#                                                                  conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 25, 25, 64)   256         add_79[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 25, 25, 64)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 25, 25, 64)   36928       activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 25, 25, 64)   256         conv2d_147[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 25, 25, 64)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 25, 25, 64)   36928       activation_108[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 25, 25, 64)   0           conv2d_148[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 25, 25, 64)   256         add_80[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 25, 25, 64)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 64)           0           activation_109[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 32)           2080        lambda_40[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 64)           2112        dense_79[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 25, 25, 1)    65          activation_109[0][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 25, 25, 64)   0           activation_109[0][0]
#                                                                  dense_80[0][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 25, 25, 64)   0           activation_109[0][0]
#                                                                  conv2d_149[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 25, 25, 64)   0           multiply_77[0][0]
#                                                                  multiply_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 12, 12, 64)   0           add_81[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 12, 12, 64)   0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 12, 12, 128)  73856       dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 12, 12, 128)  512         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 12, 12, 128)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 12, 12, 128)  147584      activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 12, 12, 128)  512         conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 12, 12, 128)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 12, 12, 128)  147584      activation_111[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 12, 12, 128)  0           conv2d_152[0][0]
#                                                                  conv2d_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 12, 12, 128)  512         add_82[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 12, 12, 128)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 12, 12, 128)  147584      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 12, 12, 128)  512         conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 12, 12, 128)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 12, 12, 128)  147584      activation_113[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 12, 12, 128)  0           conv2d_154[0][0]
#                                                                  add_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 12, 12, 128)  512         add_83[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 12, 12, 128)  0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 128)          0           activation_114[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 64)           8256        lambda_41[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 128)          8320        dense_81[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 12, 12, 1)    129         activation_114[0][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 12, 12, 128)  0           activation_114[0][0]
#                                                                  dense_82[0][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 12, 12, 128)  0           activation_114[0][0]
#                                                                  conv2d_155[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 12, 12, 128)  0           multiply_79[0][0]
#                                                                  multiply_80[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 6, 6, 128)    0           add_84[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 6, 6, 256)    295168      dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 6, 6, 256)    1024        conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 6, 6, 256)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 6, 6, 256)    590080      activation_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 6, 6, 256)    1024        conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 6, 6, 256)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 6, 6, 256)    590080      activation_116[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 6, 6, 256)    0           conv2d_158[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 6, 6, 256)    1024        add_85[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 6, 6, 256)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 6, 6, 256)    590080      activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 6, 6, 256)    1024        conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 6, 6, 256)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 6, 6, 256)    590080      activation_118[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 6, 6, 256)    0           conv2d_160[0][0]
#                                                                  add_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 6, 6, 256)    1024        add_86[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 6, 6, 256)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 12, 12, 128)  295040      activation_119[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_9[0][0]
#                                                                  add_84[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 12, 12, 256)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 12, 12, 128)  295040      dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 12, 12, 128)  512         conv2d_161[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 12, 12, 128)  0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 12, 12, 128)  147584      activation_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 12, 12, 128)  512         conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 12, 12, 128)  0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 12, 12, 128)  147584      activation_121[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 12, 12, 128)  0           conv2d_163[0][0]
#                                                                  conv2d_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 12, 12, 128)  512         add_87[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 12, 12, 128)  0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 12, 12, 128)  147584      activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 12, 12, 128)  512         conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 12, 12, 128)  0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 12, 12, 128)  147584      activation_123[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 12, 12, 128)  0           conv2d_165[0][0]
#                                                                  add_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 12, 12, 128)  512         add_88[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 12, 12, 128)  0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 128)          0           activation_124[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 64)           8256        lambda_42[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 128)          8320        dense_83[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 12, 12, 1)    129         activation_124[0][0]
# __________________________________________________________________________________________________
# multiply_81 (Multiply)          (None, 12, 12, 128)  0           activation_124[0][0]
#                                                                  dense_84[0][0]
# __________________________________________________________________________________________________
# multiply_82 (Multiply)          (None, 12, 12, 128)  0           activation_124[0][0]
#                                                                  conv2d_166[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 12, 12, 128)  0           multiply_81[0][0]
#                                                                  multiply_82[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 25, 25, 64)   73792       add_89[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 25, 25, 128)  0           conv2d_transpose_10[0][0]
#                                                                  add_81[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 25, 25, 128)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 128)          0           dropout_22[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 64)           8256        lambda_43[0][0]
# __________________________________________________________________________________________________
# dense_86 (Dense)                (None, 128)          8320        dense_85[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 25, 25, 1)    129         dropout_22[0][0]
# __________________________________________________________________________________________________
# multiply_83 (Multiply)          (None, 25, 25, 128)  0           dropout_22[0][0]
#                                                                  dense_86[0][0]
# __________________________________________________________________________________________________
# multiply_84 (Multiply)          (None, 25, 25, 128)  0           dropout_22[0][0]
#                                                                  conv2d_167[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 25, 25, 128)  0           multiply_83[0][0]
#                                                                  multiply_84[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 25, 25, 64)   73792       add_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 25, 25, 64)   256         conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 25, 25, 64)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 25, 25, 64)   36928       activation_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 25, 25, 64)   256         conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 25, 25, 64)   0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 25, 25, 64)   36928       activation_126[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 25, 25, 64)   0           conv2d_170[0][0]
#                                                                  conv2d_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 25, 25, 64)   256         add_91[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 25, 25, 64)   0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 25, 25, 64)   36928       activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 25, 25, 64)   256         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 25, 25, 64)   0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 25, 25, 64)   36928       activation_128[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 25, 25, 64)   0           conv2d_172[0][0]
#                                                                  add_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 25, 25, 64)   256         add_92[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 25, 25, 64)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 64)           0           activation_129[0][0]
# __________________________________________________________________________________________________
# dense_87 (Dense)                (None, 32)           2080        lambda_44[0][0]
# __________________________________________________________________________________________________
# dense_88 (Dense)                (None, 64)           2112        dense_87[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 25, 25, 1)    65          activation_129[0][0]
# __________________________________________________________________________________________________
# multiply_85 (Multiply)          (None, 25, 25, 64)   0           activation_129[0][0]
#                                                                  dense_88[0][0]
# __________________________________________________________________________________________________
# multiply_86 (Multiply)          (None, 25, 25, 64)   0           activation_129[0][0]
#                                                                  conv2d_173[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 25, 25, 64)   0           multiply_85[0][0]
#                                                                  multiply_86[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 50, 50, 32)   18464       add_93[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 50, 50, 64)   0           conv2d_transpose_11[0][0]
#                                                                  add_78[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 50, 50, 64)   0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 50, 50, 32)   18464       dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 50, 50, 32)   128         conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 50, 50, 32)   0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 50, 50, 32)   9248        activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 50, 50, 32)   128         conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 50, 50, 32)   0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 50, 50, 32)   9248        activation_131[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 50, 50, 32)   0           conv2d_176[0][0]
#                                                                  conv2d_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 50, 50, 32)   128         add_94[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 50, 50, 32)   0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 50, 50, 32)   9248        activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 50, 50, 32)   128         conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 50, 50, 32)   0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 50, 50, 32)   9248        activation_133[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 50, 50, 32)   0           conv2d_178[0][0]
#                                                                  add_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 50, 50, 32)   128         add_95[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 50, 50, 32)   0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 101, 101, 16) 4624        activation_134[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 101, 101, 32) 0           conv2d_transpose_12[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 101, 101, 32) 0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 101, 101, 16) 4624        dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 101, 101, 16) 64          conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 101, 101, 16) 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 101, 101, 16) 2320        activation_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 101, 101, 16) 64          conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 101, 101, 16) 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 101, 101, 16) 2320        activation_136[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 101, 101, 16) 0           conv2d_182[0][0]
#                                                                  conv2d_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 101, 101, 16) 64          add_97[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 101, 101, 16) 0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 101, 101, 16) 2320        activation_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 101, 101, 16) 64          conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 101, 101, 16) 0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 101, 101, 16) 2320        activation_138[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 101, 101, 16) 0           conv2d_184[0][0]
#                                                                  add_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 101, 101, 16) 64          add_98[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 101, 101, 16) 0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 16)           0           activation_139[0][0]
# __________________________________________________________________________________________________
# dense_91 (Dense)                (None, 8)            136         lambda_46[0][0]
# __________________________________________________________________________________________________
# dense_92 (Dense)                (None, 16)           144         dense_91[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 101, 101, 1)  17          activation_139[0][0]
# __________________________________________________________________________________________________
# multiply_89 (Multiply)          (None, 101, 101, 16) 0           activation_139[0][0]
#                                                                  dense_92[0][0]
# __________________________________________________________________________________________________
# multiply_90 (Multiply)          (None, 101, 101, 16) 0           activation_139[0][0]
#                                                                  conv2d_185[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 101, 101, 16) 0           multiply_89[0][0]
#                                                                  multiply_90[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 101, 101, 1)  17          add_99[0][0]
# ==================================================================================================
# Total params: 5,180,185
# Trainable params: 5,172,825
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
#2nd ~125epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '24th-model-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

# early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max', patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
# reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max', factor=0.5, patience=8, min_lr=0.0001, verbose=1)
save_model = ModelSave(filepath=save_file)

epochs = 50
batch_size = 32
#epochs = 100
#batch_size = 128

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr, save_model], 
                    verbose=2)

model.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/50
#  - 234s - loss: -1.7566e-01 - my_iou_metric_2: 0.8057 - val_loss: 0.0103 - val_my_iou_metric_2: 0.7882
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.78825, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 2/50
#  - 215s - loss: -2.2579e-01 - my_iou_metric_2: 0.8099 - val_loss: 0.0862 - val_my_iou_metric_2: 0.7347
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.78825
# Epoch 3/50
#  - 215s - loss: -2.2845e-01 - my_iou_metric_2: 0.8066 - val_loss: -7.2451e-03 - val_my_iou_metric_2: 0.7665
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.78825
# Epoch 4/50
#  - 214s - loss: -2.6208e-01 - my_iou_metric_2: 0.8124 - val_loss: -1.3597e-01 - val_my_iou_metric_2: 0.7911
#
# Epoch 00004: val_my_iou_metric_2 improved from 0.78825 to 0.79113, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 5/50
#  - 214s - loss: -2.7668e-01 - my_iou_metric_2: 0.8140 - val_loss: -7.0232e-02 - val_my_iou_metric_2: 0.7799
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.79113
# Epoch 6/50
#  - 214s - loss: -2.7656e-01 - my_iou_metric_2: 0.8126 - val_loss: -1.8886e-02 - val_my_iou_metric_2: 0.7685
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.79113
# Epoch 7/50
#  - 214s - loss: -3.0328e-01 - my_iou_metric_2: 0.8182 - val_loss: -1.1530e-01 - val_my_iou_metric_2: 0.7942
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.79113 to 0.79425, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 8/50
#  - 214s - loss: -2.9774e-01 - my_iou_metric_2: 0.8170 - val_loss: -1.4481e-01 - val_my_iou_metric_2: 0.7910
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.79425
# Epoch 9/50
#  - 214s - loss: -3.0446e-01 - my_iou_metric_2: 0.8197 - val_loss: -7.0186e-02 - val_my_iou_metric_2: 0.7812
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.79425
# Epoch 10/50
#  - 214s - loss: -3.3006e-01 - my_iou_metric_2: 0.8247 - val_loss: -1.1488e-01 - val_my_iou_metric_2: 0.7874
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.79425
# Epoch 11/50
#  - 214s - loss: -3.1030e-01 - my_iou_metric_2: 0.8179 - val_loss: -1.7256e-01 - val_my_iou_metric_2: 0.7977
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.79425 to 0.79775, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 12/50
#  - 214s - loss: -3.2300e-01 - my_iou_metric_2: 0.8210 - val_loss: -1.7569e-01 - val_my_iou_metric_2: 0.7928
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.79775
# Epoch 13/50
#  - 214s - loss: -3.3902e-01 - my_iou_metric_2: 0.8246 - val_loss: -1.3368e-01 - val_my_iou_metric_2: 0.7955
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.79775
# Epoch 14/50
#  - 215s - loss: -3.2537e-01 - my_iou_metric_2: 0.8215 - val_loss: -1.8613e-01 - val_my_iou_metric_2: 0.7920
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.79775
# Epoch 15/50
#  - 214s - loss: -3.4119e-01 - my_iou_metric_2: 0.8244 - val_loss: -7.6498e-02 - val_my_iou_metric_2: 0.7875
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79775
# Epoch 16/50
#  - 215s - loss: -3.4314e-01 - my_iou_metric_2: 0.8212 - val_loss: -1.2789e-01 - val_my_iou_metric_2: 0.8001
#
# Epoch 00016: val_my_iou_metric_2 improved from 0.79775 to 0.80012, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 17/50
#  - 215s - loss: -3.5568e-01 - my_iou_metric_2: 0.8266 - val_loss: -7.9788e-02 - val_my_iou_metric_2: 0.7734
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.80012
# Epoch 18/50
#  - 214s - loss: -3.7020e-01 - my_iou_metric_2: 0.8287 - val_loss: -5.1231e-02 - val_my_iou_metric_2: 0.7642
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80012
# Epoch 19/50
#  - 214s - loss: -3.6501e-01 - my_iou_metric_2: 0.8281 - val_loss: 0.1123 - val_my_iou_metric_2: 0.7789
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80012
# Epoch 20/50
#  - 214s - loss: -3.6684e-01 - my_iou_metric_2: 0.8285 - val_loss: -1.6309e-01 - val_my_iou_metric_2: 0.8054
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.80012 to 0.80537, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 21/50
#  - 215s - loss: -3.5868e-01 - my_iou_metric_2: 0.8267 - val_loss: -1.8246e-01 - val_my_iou_metric_2: 0.7981
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.80537
# Epoch 22/50
#  - 214s - loss: -3.7064e-01 - my_iou_metric_2: 0.8282 - val_loss: 0.1746 - val_my_iou_metric_2: 0.7481
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.80537
# Epoch 23/50
#  - 214s - loss: -3.6381e-01 - my_iou_metric_2: 0.8280 - val_loss: -4.2544e-02 - val_my_iou_metric_2: 0.7768
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.80537
# Epoch 24/50
#  - 214s - loss: -3.6903e-01 - my_iou_metric_2: 0.8296 - val_loss: -1.3484e-01 - val_my_iou_metric_2: 0.7987
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.80537
# Epoch 25/50
#  - 214s - loss: -3.9852e-01 - my_iou_metric_2: 0.8340 - val_loss: -9.3855e-02 - val_my_iou_metric_2: 0.7865
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.80537
# Epoch 26/50
#  - 214s - loss: -3.8953e-01 - my_iou_metric_2: 0.8337 - val_loss: -1.2652e-01 - val_my_iou_metric_2: 0.8056
#
# Epoch 00026: val_my_iou_metric_2 improved from 0.80537 to 0.80562, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 27/50
#  - 214s - loss: -3.8112e-01 - my_iou_metric_2: 0.8290 - val_loss: 0.0310 - val_my_iou_metric_2: 0.7926
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 28/50
#  - 214s - loss: -3.9472e-01 - my_iou_metric_2: 0.8324 - val_loss: -7.2349e-02 - val_my_iou_metric_2: 0.7766
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 29/50
#  - 214s - loss: -3.8217e-01 - my_iou_metric_2: 0.8310 - val_loss: 0.0136 - val_my_iou_metric_2: 0.7525
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 30/50
#  - 214s - loss: -3.8633e-01 - my_iou_metric_2: 0.8320 - val_loss: -1.7058e-01 - val_my_iou_metric_2: 0.7987
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 31/50
#  - 214s - loss: -4.1777e-01 - my_iou_metric_2: 0.8381 - val_loss: -3.6862e-02 - val_my_iou_metric_2: 0.7892
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 32/50
#  - 215s - loss: -4.0775e-01 - my_iou_metric_2: 0.8347 - val_loss: -2.0958e-01 - val_my_iou_metric_2: 0.8005
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 33/50
#  - 215s - loss: -4.0940e-01 - my_iou_metric_2: 0.8363 - val_loss: -3.7737e-02 - val_my_iou_metric_2: 0.7797
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 34/50
#  - 215s - loss: -4.0680e-01 - my_iou_metric_2: 0.8350 - val_loss: -3.3405e-02 - val_my_iou_metric_2: 0.7907
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.80562
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 35/50
#  - 214s - loss: -4.7251e-01 - my_iou_metric_2: 0.8495 - val_loss: -1.8322e-01 - val_my_iou_metric_2: 0.8055
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.80562
# Epoch 36/50
#  - 214s - loss: -4.7733e-01 - my_iou_metric_2: 0.8505 - val_loss: -2.5434e-01 - val_my_iou_metric_2: 0.8114
#
# Epoch 00036: val_my_iou_metric_2 improved from 0.80562 to 0.81137, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 37/50
#  - 215s - loss: -4.8332e-01 - my_iou_metric_2: 0.8529 - val_loss: -2.2673e-01 - val_my_iou_metric_2: 0.8049
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.81137
# Epoch 38/50
#  - 214s - loss: -4.9315e-01 - my_iou_metric_2: 0.8536 - val_loss: -1.7137e-01 - val_my_iou_metric_2: 0.8142
#
# Epoch 00038: val_my_iou_metric_2 improved from 0.81137 to 0.81425, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 39/50
#  - 214s - loss: -4.9897e-01 - my_iou_metric_2: 0.8522 - val_loss: -1.8400e-01 - val_my_iou_metric_2: 0.8157
#
# Epoch 00039: val_my_iou_metric_2 improved from 0.81425 to 0.81575, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 40/50
#  - 214s - loss: -4.9068e-01 - my_iou_metric_2: 0.8520 - val_loss: -2.1974e-01 - val_my_iou_metric_2: 0.8144
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.81575
# Epoch 41/50
#  - 214s - loss: -5.0713e-01 - my_iou_metric_2: 0.8550 - val_loss: -2.1942e-01 - val_my_iou_metric_2: 0.8055
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.81575
# Epoch 42/50
#  - 214s - loss: -4.9238e-01 - my_iou_metric_2: 0.8535 - val_loss: -1.7337e-01 - val_my_iou_metric_2: 0.8250
#
# Epoch 00042: val_my_iou_metric_2 improved from 0.81575 to 0.82500, saving model to 24th-model-tgs-salt-20181014001046.h5
# Epoch 43/50
#  - 214s - loss: -4.9405e-01 - my_iou_metric_2: 0.8534 - val_loss: -1.4639e-01 - val_my_iou_metric_2: 0.7976
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 44/50
#  - 214s - loss: -4.9080e-01 - my_iou_metric_2: 0.8520 - val_loss: -2.3368e-01 - val_my_iou_metric_2: 0.8130
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 45/50
#  - 214s - loss: -5.1267e-01 - my_iou_metric_2: 0.8553 - val_loss: -1.3340e-01 - val_my_iou_metric_2: 0.8119
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 46/50
#  - 214s - loss: -5.1116e-01 - my_iou_metric_2: 0.8564 - val_loss: -7.5277e-02 - val_my_iou_metric_2: 0.8070
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 47/50
#  - 214s - loss: -5.0410e-01 - my_iou_metric_2: 0.8532 - val_loss: -1.7945e-01 - val_my_iou_metric_2: 0.8128
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 48/50
#  - 214s - loss: -5.1228e-01 - my_iou_metric_2: 0.8535 - val_loss: -2.3556e-01 - val_my_iou_metric_2: 0.8167
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 49/50
#  - 214s - loss: -5.1748e-01 - my_iou_metric_2: 0.8555 - val_loss: -1.2390e-01 - val_my_iou_metric_2: 0.8196
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.82500
# Epoch 50/50
#  - 215s - loss: -5.2302e-01 - my_iou_metric_2: 0.8558 - val_loss: -2.0945e-01 - val_my_iou_metric_2: 0.8159
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.82500
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.

# %%
#2nd 50epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model-50epochs-tgs-salt-Nadam-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5'
model = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric_2': my_iou_metric_2, 'lovasz_loss': lovasz_loss})

# early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max', patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
# reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max', factor=0.5, patience=8, min_lr=0.0001, verbose=1)

epochs = 25
batch_size = 32
#epochs = 100
#batch_size = 128

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model.save("drive/My Drive/kaggle/{}".format(save_file))

# %%
#2nd 75epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model-75-epochs-tgs-salt_{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5'
model = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric_2': my_iou_metric_2, 'lovasz_loss': lovasz_loss})

# early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max', patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
# reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max', factor=0.5, patience=8, min_lr=0.0001, verbose=1)

epochs = 25
batch_size = 32
#epochs = 100
#batch_size = 128

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model.save("drive/My Drive/kaggle/{}".format(save_file))

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
from google.colab import drive
drive.mount('/content/drive')
model = load_model('drive/My Drive/kaggle/7-model-tgs-salt-Nadam-20181008141024.h5', custom_objects={'my_iou_metric_2': my_iou_metric_2, 'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
#preds_valid = predict_result(model1, x_valid, img_size_target)
preds_valid = predict_result(model, x_valid, img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
    #temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in thresholds])
print(ious)
# Out:
# [0.805625 0.8085   0.809125 0.80975  0.81175  0.811625 0.8125   0.81325
#  0.813875 0.813875 0.814125 0.81375  0.813375 0.813875 0.815875 0.817125
#  0.816875 0.81725  0.82     0.818375 0.818125 0.818875 0.8185   0.8185
#  0.818375 0.818125 0.817875 0.8185   0.81775  0.81775  0.81675 ]

# %%
# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("../content/test/{}.png".format(idx), grayscale = True))) / 255 for idx in test_df.index]).reshape(-1, img_size_target, img_size_target, 1)

# %%
#preds_test = predict_result(model1, x_test,img_size_target)
preds_test = predict_result(model, x_test,img_size_target)

# %%
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(test_df.index.values)}
# Out:
# Usedtime = 6.753081321716309 s

# %%
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
#submit_name = '24th-model1-tgs-salt-submission_{}.csv'.format(now)
submit_name = '25th-model-tgs-salt-submission_{}.csv'.format(now)


sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submit_name)

# %%
t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# Kernel run time = 3.981688062614865 hours

# %%
# !cp "../content/$submit_name" "drive/My Drive/kaggle/"
# !kaggle competitions submit -c tgs-salt-identification-challenge -f "drive/My Drive/kaggle/$submit_name" -m "$now"
# Out:
# Successfully submitted to TGS Salt Identification Challenge
