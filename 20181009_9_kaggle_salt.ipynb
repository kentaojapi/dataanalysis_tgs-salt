# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kentaojapi/dataanalysis_tgs-salt/blob/master/20181009_9_kaggle_salt.ipynb)

# %%
# download API key from google drive
## Original: https://colab.research.google.com/drive/1eufc8aNCdjHbrBhuy7M7X6BGyzAyRbrF#scrollTo=y5_288BYp6H1
## When you run for the first time, you will see a link to authenticate.

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/content/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Download 100%.

# %%
# !ls
# Out:
# 13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5  sample_data
# 14th-model-tgs-salt-submission_20181010231059.csv     sample_submission.csv
# adc.json					      test
# depths.csv					      train
# drive						      train.csv
# masks

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
# !kaggle competitions download -c tgs-salt-identification-challenge
# !unzip train.zip
# !mv images/ train/
# !unzip test.zip
# !mv images/ test/
# !rm train.zip
# !rm test.zip
# !df -h
from IPython.display import clear_output
clear_output()

# %%
import os
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

# import cv2
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
t_start = time.time()

# %%
ids= ['1f1cc6b3a4','5b7c160d0d','6c40978ddf','7dfdf6eeb8','7e5a6e5013']
plt.figure(figsize=(20,10))
for j, img_name in enumerate(ids):
    q = j+1
    img = load_img('../content/train/' + img_name + '.png')
    img_mask = load_img('../content/masks/' + img_name + '.png')
    
    plt.subplot(1,2*(1+len(ids)),q*2-1)
    plt.imshow(img)
    plt.subplot(1,2*(1+len(ids)),q*2)
    plt.imshow(img_mask)
plt.show()

# %%
# version = 5
# basic_name = f'Unet_resnet_v{version}'
# save_model_name = basic_name + '.model'
# submission_file = basic_name + '.csv'

# print(save_model_name)
# print(submission_file)

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../content/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../content/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("../content/train/{}.png".format(idx), grayscale=True)) / 255 for idx in train_df.index]

# %%
train_df["masks"] = [np.array(load_img("../content/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in train_df.index]

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5,0,'Coverage class')

# %%
#Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5,1,'Depth distribution')

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
        x = Dropout(0.3)(x) #add
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1, start_neurons * 1)
    conv1 = residual_block(conv1, start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)
    
    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)
                                  
    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)

    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
                                  
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
#             metric.append(1)
#             continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        #loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16, 0.5)

model1 = Model(input_layer, output_layer)

#c = optimizers.adam(lr = 0.01)
c = optimizers.Nadam(lr=0.002)
#c = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

model1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 101, 101, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 101, 101, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 101, 101, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 101, 101, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 101, 101, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 101, 101, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 101, 101, 16) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 101, 101, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 101, 101, 16) 0           conv2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 101, 101, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 101, 101, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 101, 101, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 101, 101, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 101, 101, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 101, 101, 16) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 101, 101, 16) 2320        dropout_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 101, 101, 16) 0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 50, 50, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 32)   4640        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 50, 50, 32)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   9248        dropout_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 50, 50, 32)   0           conv2d_8[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 50, 50, 32)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 32)   0           conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 32)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25, 25, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 64)   18496       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 25, 25, 64)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 25, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 25, 25, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 25, 25, 64)   0           conv2d_15[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 128)  73856       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 12, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 12, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 12, 12, 128)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 128)  147584      dropout_10[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 128)  0           conv2d_18[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 12, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 12, 12, 128)  0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 128)  147584      dropout_11[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 128)  0           conv2d_20[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 128)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 6, 6, 256)    295168      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 6, 6, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 6, 6, 256)    0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 256)    590080      dropout_13[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 256)    0           conv2d_23[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 6, 6, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 6, 6, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 6, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 6, 6, 256)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 6, 6, 256)    590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 256)    0           conv2d_25[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 6, 6, 256)    1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 12, 12, 128)  295040      activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 12, 128)  295040      dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 12, 12, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 12, 12, 128)  0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 128)  147584      dropout_16[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 128)  0           conv2d_28[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 12, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 12, 12, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 128)  147584      dropout_17[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 128)  0           conv2d_30[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 25, 25, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 25, 25, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 25, 64)   73792       dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 25, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 25, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 25, 25, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 25, 25, 64)   0           activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 25, 25, 64)   36928       dropout_19[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 25, 25, 64)   0           conv2d_33[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 25, 25, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 25, 25, 64)   0           activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 25, 25, 64)   36928       dropout_20[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 25, 25, 64)   0           conv2d_35[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 50, 50, 32)   18464       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 50, 50, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 50, 50, 32)   18464       dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 50, 50, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 50, 50, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 50, 50, 32)   0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 50, 32)   9248        dropout_22[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 50, 50, 32)   0           conv2d_38[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 32)   128         add_15[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 50, 50, 32)   0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 32)   9248        dropout_23[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 50, 50, 32)   0           conv2d_40[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 32)   128         add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 101, 101, 16) 4624        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 101, 101, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 101, 101, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 101, 101, 16) 4624        dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 101, 101, 16) 64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 101, 101, 16) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 101, 101, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 101, 101, 16) 64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 101, 101, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 101, 101, 16) 0           activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 101, 101, 16) 2320        dropout_25[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 101, 101, 16) 0           conv2d_43[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 101, 101, 16) 64          add_17[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 101, 101, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 101, 101, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 101, 101, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 101, 101, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 101, 101, 16) 0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 101, 101, 16) 2320        dropout_26[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 101, 101, 16) 0           conv2d_45[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 101, 101, 16) 64          add_18[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 101, 101, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 101, 101, 1)  17          activation_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 101, 101, 1)  0           conv2d_46[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
#1st-25epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-50epochs-model1-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

#epochs = 100
epochs = 25
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 128s - loss: 0.3693 - my_iou_metric: 0.3928 - val_loss: 0.5157 - val_my_iou_metric: 0.3631
#
# Epoch 00001: my_iou_metric improved from -inf to 0.39280, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 2/25
#  - 115s - loss: 0.3006 - my_iou_metric: 0.5041 - val_loss: 0.3966 - val_my_iou_metric: 0.5123
#
# Epoch 00002: my_iou_metric improved from 0.39280 to 0.50414, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 3/25
#  - 115s - loss: 0.2567 - my_iou_metric: 0.5358 - val_loss: 0.3273 - val_my_iou_metric: 0.4842
#
# Epoch 00003: my_iou_metric improved from 0.50414 to 0.53578, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 4/25
#  - 115s - loss: 0.2388 - my_iou_metric: 0.5634 - val_loss: 0.2943 - val_my_iou_metric: 0.4962
#
# Epoch 00004: my_iou_metric improved from 0.53578 to 0.56339, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 5/25
#  - 115s - loss: 0.2192 - my_iou_metric: 0.5791 - val_loss: 0.8270 - val_my_iou_metric: 0.3836
#
# Epoch 00005: my_iou_metric improved from 0.56339 to 0.57908, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 6/25
#  - 115s - loss: 0.2133 - my_iou_metric: 0.5923 - val_loss: 0.2252 - val_my_iou_metric: 0.5958
#
# Epoch 00006: my_iou_metric improved from 0.57908 to 0.59234, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 7/25
#  - 115s - loss: 0.2006 - my_iou_metric: 0.6080 - val_loss: 0.2632 - val_my_iou_metric: 0.6178
#
# Epoch 00007: my_iou_metric improved from 0.59234 to 0.60802, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 8/25
#  - 115s - loss: 0.1955 - my_iou_metric: 0.6149 - val_loss: 0.2089 - val_my_iou_metric: 0.6824
#
# Epoch 00008: my_iou_metric improved from 0.60802 to 0.61492, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 9/25
#  - 115s - loss: 0.1941 - my_iou_metric: 0.6151 - val_loss: 0.2986 - val_my_iou_metric: 0.6183
#
# Epoch 00009: my_iou_metric improved from 0.61492 to 0.61509, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 10/25
#  - 115s - loss: 0.1872 - my_iou_metric: 0.6294 - val_loss: 0.4712 - val_my_iou_metric: 0.5691
#
# Epoch 00010: my_iou_metric improved from 0.61509 to 0.62936, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 11/25
#  - 115s - loss: 0.1778 - my_iou_metric: 0.6403 - val_loss: 0.2851 - val_my_iou_metric: 0.6159
#
# Epoch 00011: my_iou_metric improved from 0.62936 to 0.64025, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 12/25
#  - 115s - loss: 0.1709 - my_iou_metric: 0.6565 - val_loss: 0.1864 - val_my_iou_metric: 0.6939
#
# Epoch 00012: my_iou_metric improved from 0.64025 to 0.65648, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 13/25
#  - 115s - loss: 0.1653 - my_iou_metric: 0.6608 - val_loss: 0.1834 - val_my_iou_metric: 0.6649
#
# Epoch 00013: my_iou_metric improved from 0.65648 to 0.66083, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 14/25
#  - 115s - loss: 0.1653 - my_iou_metric: 0.6650 - val_loss: 0.2174 - val_my_iou_metric: 0.6205
#
# Epoch 00014: my_iou_metric improved from 0.66083 to 0.66505, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 15/25
#  - 115s - loss: 0.1634 - my_iou_metric: 0.6724 - val_loss: 0.2370 - val_my_iou_metric: 0.6605
#
# Epoch 00015: my_iou_metric improved from 0.66505 to 0.67236, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 16/25
#  - 115s - loss: 0.1550 - my_iou_metric: 0.6775 - val_loss: 0.1993 - val_my_iou_metric: 0.6994
#
# Epoch 00016: my_iou_metric improved from 0.67236 to 0.67750, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 17/25
#  - 115s - loss: 0.1529 - my_iou_metric: 0.6760 - val_loss: 0.3079 - val_my_iou_metric: 0.6106
#
# Epoch 00017: my_iou_metric did not improve from 0.67750
# Epoch 18/25
#  - 115s - loss: 0.1478 - my_iou_metric: 0.6915 - val_loss: 0.2275 - val_my_iou_metric: 0.6914
#
# Epoch 00018: my_iou_metric improved from 0.67750 to 0.69150, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 19/25
#  - 115s - loss: 0.1442 - my_iou_metric: 0.6961 - val_loss: 0.2906 - val_my_iou_metric: 0.5943
#
# Epoch 00019: my_iou_metric improved from 0.69150 to 0.69606, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 20/25
#  - 115s - loss: 0.1411 - my_iou_metric: 0.6957 - val_loss: 0.1490 - val_my_iou_metric: 0.7276
#
# Epoch 00020: my_iou_metric did not improve from 0.69606
# Epoch 21/25
#  - 114s - loss: 0.1409 - my_iou_metric: 0.6990 - val_loss: 0.1737 - val_my_iou_metric: 0.6977
#
# Epoch 00021: my_iou_metric improved from 0.69606 to 0.69897, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 22/25
#  - 115s - loss: 0.1387 - my_iou_metric: 0.7080 - val_loss: 0.1486 - val_my_iou_metric: 0.7148
#
# Epoch 00022: my_iou_metric improved from 0.69897 to 0.70805, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 23/25
#  - 115s - loss: 0.1352 - my_iou_metric: 0.7036 - val_loss: 0.1715 - val_my_iou_metric: 0.7316
#
# Epoch 00023: my_iou_metric did not improve from 0.70805
# Epoch 24/25
#  - 115s - loss: 0.1358 - my_iou_metric: 0.7143 - val_loss: 0.1897 - val_my_iou_metric: 0.6385
#
# Epoch 00024: my_iou_metric improved from 0.70805 to 0.71427, saving model to 13th-50epochs-model1-tgs-salt-20181010031048.h5
# Epoch 25/25
#  - 115s - loss: 0.1341 - my_iou_metric: 0.7105 - val_loss: 0.1716 - val_my_iou_metric: 0.7079
#
# Epoch 00025: my_iou_metric did not improve from 0.71427

# %%
# 1st-50epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model1-50epochs-2-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 115s - loss: 0.1287 - my_iou_metric: 0.7140 - val_loss: 0.1829 - val_my_iou_metric: 0.6485
#
# Epoch 00001: my_iou_metric improved from -inf to 0.71397, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 2/25
#  - 115s - loss: 0.1312 - my_iou_metric: 0.7133 - val_loss: 0.1503 - val_my_iou_metric: 0.7271
#
# Epoch 00002: my_iou_metric did not improve from 0.71397
# Epoch 3/25
#  - 115s - loss: 0.1225 - my_iou_metric: 0.7276 - val_loss: 0.3265 - val_my_iou_metric: 0.6258
#
# Epoch 00003: my_iou_metric improved from 0.71397 to 0.72763, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 4/25
#  - 115s - loss: 0.1278 - my_iou_metric: 0.7290 - val_loss: 0.3004 - val_my_iou_metric: 0.5722
#
# Epoch 00004: my_iou_metric improved from 0.72763 to 0.72898, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 5/25
#  - 114s - loss: 0.1227 - my_iou_metric: 0.7282 - val_loss: 0.1486 - val_my_iou_metric: 0.7119
#
# Epoch 00005: my_iou_metric did not improve from 0.72898
# Epoch 6/25
#  - 114s - loss: 0.1188 - my_iou_metric: 0.7314 - val_loss: 0.2061 - val_my_iou_metric: 0.7066
#
# Epoch 00006: my_iou_metric improved from 0.72898 to 0.73136, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 7/25
#  - 115s - loss: 0.1228 - my_iou_metric: 0.7302 - val_loss: 0.1463 - val_my_iou_metric: 0.7272
#
# Epoch 00007: my_iou_metric did not improve from 0.73136
# Epoch 8/25
#  - 115s - loss: 0.1174 - my_iou_metric: 0.7315 - val_loss: 0.1784 - val_my_iou_metric: 0.7370
#
# Epoch 00008: my_iou_metric improved from 0.73136 to 0.73155, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 9/25
#  - 115s - loss: 0.1172 - my_iou_metric: 0.7348 - val_loss: 0.1342 - val_my_iou_metric: 0.7501
#
# Epoch 00009: my_iou_metric improved from 0.73155 to 0.73478, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 10/25
#  - 115s - loss: 0.1202 - my_iou_metric: 0.7328 - val_loss: 0.1358 - val_my_iou_metric: 0.7433
#
# Epoch 00010: my_iou_metric did not improve from 0.73478
# Epoch 11/25
#  - 115s - loss: 0.1164 - my_iou_metric: 0.7381 - val_loss: 0.3847 - val_my_iou_metric: 0.6256
#
# Epoch 00011: my_iou_metric improved from 0.73478 to 0.73808, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 12/25
#  - 115s - loss: 0.1162 - my_iou_metric: 0.7369 - val_loss: 0.1644 - val_my_iou_metric: 0.7074
#
# Epoch 00012: my_iou_metric did not improve from 0.73808
# Epoch 13/25
#  - 115s - loss: 0.1117 - my_iou_metric: 0.7362 - val_loss: 0.1556 - val_my_iou_metric: 0.7235
#
# Epoch 00013: my_iou_metric did not improve from 0.73808
# Epoch 14/25
#  - 115s - loss: 0.1099 - my_iou_metric: 0.7447 - val_loss: 0.1496 - val_my_iou_metric: 0.7309
#
# Epoch 00014: my_iou_metric improved from 0.73808 to 0.74469, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 15/25
#  - 115s - loss: 0.1088 - my_iou_metric: 0.7493 - val_loss: 0.1373 - val_my_iou_metric: 0.7374
#
# Epoch 00015: my_iou_metric improved from 0.74469 to 0.74934, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 16/25
#  - 115s - loss: 0.1105 - my_iou_metric: 0.7423 - val_loss: 0.1588 - val_my_iou_metric: 0.7020
#
# Epoch 00016: my_iou_metric did not improve from 0.74934
# Epoch 17/25
#  - 115s - loss: 0.1095 - my_iou_metric: 0.7464 - val_loss: 0.1451 - val_my_iou_metric: 0.7464
#
# Epoch 00017: my_iou_metric did not improve from 0.74934
# Epoch 18/25
#  - 115s - loss: 0.1078 - my_iou_metric: 0.7510 - val_loss: 0.1516 - val_my_iou_metric: 0.7169
#
# Epoch 00018: my_iou_metric improved from 0.74934 to 0.75098, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 19/25
#  - 115s - loss: 0.1072 - my_iou_metric: 0.7480 - val_loss: 0.2051 - val_my_iou_metric: 0.7339
#
# Epoch 00019: my_iou_metric did not improve from 0.75098
# Epoch 20/25
#  - 115s - loss: 0.1113 - my_iou_metric: 0.7399 - val_loss: 0.1347 - val_my_iou_metric: 0.7510
#
# Epoch 00020: my_iou_metric did not improve from 0.75098
# Epoch 21/25
#  - 115s - loss: 0.1030 - my_iou_metric: 0.7558 - val_loss: 0.1761 - val_my_iou_metric: 0.7340
#
# Epoch 00021: my_iou_metric improved from 0.75098 to 0.75577, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 22/25
#  - 115s - loss: 0.1022 - my_iou_metric: 0.7555 - val_loss: 0.1354 - val_my_iou_metric: 0.7694
#
# Epoch 00022: my_iou_metric did not improve from 0.75577
# Epoch 23/25
#  - 115s - loss: 0.1062 - my_iou_metric: 0.7538 - val_loss: 0.1493 - val_my_iou_metric: 0.7441
#
# Epoch 00023: my_iou_metric did not improve from 0.75577
# Epoch 24/25
#  - 115s - loss: 0.1034 - my_iou_metric: 0.7559 - val_loss: 0.1257 - val_my_iou_metric: 0.7659
#
# Epoch 00024: my_iou_metric improved from 0.75577 to 0.75592, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5
# Epoch 25/25
#  - 115s - loss: 0.1017 - my_iou_metric: 0.7596 - val_loss: 0.1634 - val_my_iou_metric: 0.7343
#
# Epoch 00025: my_iou_metric improved from 0.75592 to 0.75961, saving model to 13th-model1-50epochs-2-tgs-salt-20181010051010.h5

# %%
# 1st-75epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model1-75epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 115s - loss: 0.0987 - my_iou_metric: 0.7584 - val_loss: 0.1377 - val_my_iou_metric: 0.7294
#
# Epoch 00001: my_iou_metric improved from -inf to 0.75841, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 2/25
#  - 115s - loss: 0.0981 - my_iou_metric: 0.7608 - val_loss: 0.1208 - val_my_iou_metric: 0.7634
#
# Epoch 00002: my_iou_metric improved from 0.75841 to 0.76075, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 3/25
#  - 115s - loss: 0.0955 - my_iou_metric: 0.7633 - val_loss: 0.1644 - val_my_iou_metric: 0.7368
#
# Epoch 00003: my_iou_metric improved from 0.76075 to 0.76327, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 4/25
#  - 115s - loss: 0.0970 - my_iou_metric: 0.7615 - val_loss: 0.2185 - val_my_iou_metric: 0.7205
#
# Epoch 00004: my_iou_metric did not improve from 0.76327
# Epoch 5/25
#  - 115s - loss: 0.0985 - my_iou_metric: 0.7605 - val_loss: 0.1296 - val_my_iou_metric: 0.7534
#
# Epoch 00005: my_iou_metric did not improve from 0.76327
# Epoch 6/25
#  - 115s - loss: 0.0965 - my_iou_metric: 0.7622 - val_loss: 0.1773 - val_my_iou_metric: 0.6839
#
# Epoch 00006: my_iou_metric did not improve from 0.76327
# Epoch 7/25
#  - 115s - loss: 0.0973 - my_iou_metric: 0.7647 - val_loss: 0.1474 - val_my_iou_metric: 0.7695
#
# Epoch 00007: my_iou_metric improved from 0.76327 to 0.76472, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 8/25
#  - 115s - loss: 0.0943 - my_iou_metric: 0.7627 - val_loss: 0.1565 - val_my_iou_metric: 0.7684
#
# Epoch 00008: my_iou_metric did not improve from 0.76472
# Epoch 9/25
#  - 115s - loss: 0.0953 - my_iou_metric: 0.7638 - val_loss: 0.2222 - val_my_iou_metric: 0.7194
#
# Epoch 00009: my_iou_metric did not improve from 0.76472
# Epoch 10/25
#  - 115s - loss: 0.0992 - my_iou_metric: 0.7616 - val_loss: 0.1352 - val_my_iou_metric: 0.7729
#
# Epoch 00010: my_iou_metric did not improve from 0.76472
# Epoch 11/25
#  - 115s - loss: 0.0923 - my_iou_metric: 0.7679 - val_loss: 0.1817 - val_my_iou_metric: 0.6980
#
# Epoch 00011: my_iou_metric improved from 0.76472 to 0.76794, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 12/25
#  - 115s - loss: 0.0979 - my_iou_metric: 0.7574 - val_loss: 0.1971 - val_my_iou_metric: 0.7246
#
# Epoch 00012: my_iou_metric did not improve from 0.76794
# Epoch 13/25
#  - 114s - loss: 0.0940 - my_iou_metric: 0.7670 - val_loss: 0.1531 - val_my_iou_metric: 0.7591
#
# Epoch 00013: my_iou_metric did not improve from 0.76794
# Epoch 14/25
#  - 115s - loss: 0.1004 - my_iou_metric: 0.7606 - val_loss: 0.1411 - val_my_iou_metric: 0.7671
#
# Epoch 00014: my_iou_metric did not improve from 0.76794
# Epoch 15/25
#  - 115s - loss: 0.0907 - my_iou_metric: 0.7684 - val_loss: 0.1903 - val_my_iou_metric: 0.7025
#
# Epoch 00015: my_iou_metric improved from 0.76794 to 0.76841, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 16/25
#  - 114s - loss: 0.0900 - my_iou_metric: 0.7713 - val_loss: 0.1378 - val_my_iou_metric: 0.7679
#
# Epoch 00016: my_iou_metric improved from 0.76841 to 0.77133, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 17/25
#  - 115s - loss: 0.0889 - my_iou_metric: 0.7708 - val_loss: 0.1653 - val_my_iou_metric: 0.7331
#
# Epoch 00017: my_iou_metric did not improve from 0.77133
# Epoch 18/25
#  - 115s - loss: 0.0887 - my_iou_metric: 0.7751 - val_loss: 0.1309 - val_my_iou_metric: 0.7711
#
# Epoch 00018: my_iou_metric improved from 0.77133 to 0.77508, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 19/25
#  - 114s - loss: 0.0866 - my_iou_metric: 0.7762 - val_loss: 0.1197 - val_my_iou_metric: 0.7845
#
# Epoch 00019: my_iou_metric improved from 0.77508 to 0.77619, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 20/25
#  - 115s - loss: 0.0898 - my_iou_metric: 0.7709 - val_loss: 0.2165 - val_my_iou_metric: 0.7274
#
# Epoch 00020: my_iou_metric did not improve from 0.77619
# Epoch 21/25
#  - 115s - loss: 0.0904 - my_iou_metric: 0.7728 - val_loss: 0.1421 - val_my_iou_metric: 0.7539
#
# Epoch 00021: my_iou_metric did not improve from 0.77619
# Epoch 22/25
#  - 115s - loss: 0.0859 - my_iou_metric: 0.7711 - val_loss: 0.1237 - val_my_iou_metric: 0.7746
#
# Epoch 00022: my_iou_metric did not improve from 0.77619
# Epoch 23/25
#  - 115s - loss: 0.0836 - my_iou_metric: 0.7783 - val_loss: 0.2083 - val_my_iou_metric: 0.6955
#
# Epoch 00023: my_iou_metric improved from 0.77619 to 0.77833, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 24/25
#  - 114s - loss: 0.0818 - my_iou_metric: 0.7824 - val_loss: 0.1286 - val_my_iou_metric: 0.7630
#
# Epoch 00024: my_iou_metric improved from 0.77833 to 0.78242, saving model to 13th-model1-75epochs-tgs-salt-20181010051012.h5
# Epoch 25/25
#  - 115s - loss: 0.0897 - my_iou_metric: 0.7654 - val_loss: 0.1500 - val_my_iou_metric: 0.7358
#
# Epoch 00025: my_iou_metric did not improve from 0.78242

# %%
# 1st-100epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model1-100epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 115s - loss: 0.0836 - my_iou_metric: 0.7777 - val_loss: 0.1234 - val_my_iou_metric: 0.7769
#
# Epoch 00001: my_iou_metric improved from -inf to 0.77767, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 2/25
#  - 115s - loss: 0.0842 - my_iou_metric: 0.7760 - val_loss: 0.1238 - val_my_iou_metric: 0.7710
#
# Epoch 00002: my_iou_metric did not improve from 0.77767
# Epoch 3/25
#  - 115s - loss: 0.0824 - my_iou_metric: 0.7778 - val_loss: 0.1493 - val_my_iou_metric: 0.7671
#
# Epoch 00003: my_iou_metric improved from 0.77767 to 0.77783, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 4/25
#  - 112s - loss: 0.0825 - my_iou_metric: 0.7791 - val_loss: 0.1411 - val_my_iou_metric: 0.7771
#
# Epoch 00004: my_iou_metric improved from 0.77783 to 0.77913, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 5/25
#  - 114s - loss: 0.0757 - my_iou_metric: 0.7900 - val_loss: 0.1235 - val_my_iou_metric: 0.7883
#
# Epoch 00005: my_iou_metric improved from 0.77913 to 0.79002, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 6/25
#  - 115s - loss: 0.0820 - my_iou_metric: 0.7761 - val_loss: 0.1712 - val_my_iou_metric: 0.7486
#
# Epoch 00006: my_iou_metric did not improve from 0.79002
# Epoch 7/25
#  - 114s - loss: 0.0811 - my_iou_metric: 0.7841 - val_loss: 0.1629 - val_my_iou_metric: 0.7529
#
# Epoch 00007: my_iou_metric did not improve from 0.79002
# Epoch 8/25
#  - 115s - loss: 0.0825 - my_iou_metric: 0.7812 - val_loss: 0.1692 - val_my_iou_metric: 0.7381
#
# Epoch 00008: my_iou_metric did not improve from 0.79002
# Epoch 9/25
#  - 115s - loss: 0.0817 - my_iou_metric: 0.7840 - val_loss: 0.1262 - val_my_iou_metric: 0.7796
#
# Epoch 00009: my_iou_metric did not improve from 0.79002
# Epoch 10/25
#  - 115s - loss: 0.0732 - my_iou_metric: 0.7885 - val_loss: 0.2142 - val_my_iou_metric: 0.6797
#
# Epoch 00010: my_iou_metric did not improve from 0.79002
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 11/25
#  - 115s - loss: 0.0750 - my_iou_metric: 0.7925 - val_loss: 0.1417 - val_my_iou_metric: 0.7812
#
# Epoch 00011: my_iou_metric improved from 0.79002 to 0.79255, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 12/25
#  - 115s - loss: 0.0667 - my_iou_metric: 0.8002 - val_loss: 0.1329 - val_my_iou_metric: 0.7747
#
# Epoch 00012: my_iou_metric improved from 0.79255 to 0.80019, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 13/25
#  - 115s - loss: 0.0661 - my_iou_metric: 0.8026 - val_loss: 0.1278 - val_my_iou_metric: 0.7765
#
# Epoch 00013: my_iou_metric improved from 0.80019 to 0.80259, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 14/25
#  - 115s - loss: 0.0653 - my_iou_metric: 0.8043 - val_loss: 0.1364 - val_my_iou_metric: 0.7831
#
# Epoch 00014: my_iou_metric improved from 0.80259 to 0.80431, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 15/25
#  - 115s - loss: 0.0653 - my_iou_metric: 0.7982 - val_loss: 0.1320 - val_my_iou_metric: 0.7576
#
# Epoch 00015: my_iou_metric did not improve from 0.80431
# Epoch 16/25
#  - 115s - loss: 0.0650 - my_iou_metric: 0.7970 - val_loss: 0.1493 - val_my_iou_metric: 0.7761
#
# Epoch 00016: my_iou_metric did not improve from 0.80431
# Epoch 17/25
#  - 115s - loss: 0.0649 - my_iou_metric: 0.8025 - val_loss: 0.1642 - val_my_iou_metric: 0.7490
#
# Epoch 00017: my_iou_metric did not improve from 0.80431
# Epoch 18/25
#  - 115s - loss: 0.0675 - my_iou_metric: 0.7996 - val_loss: 0.1225 - val_my_iou_metric: 0.7906
#
# Epoch 00018: my_iou_metric did not improve from 0.80431
# Epoch 19/25
#  - 115s - loss: 0.0661 - my_iou_metric: 0.8053 - val_loss: 0.1526 - val_my_iou_metric: 0.7773
#
# Epoch 00019: my_iou_metric improved from 0.80431 to 0.80533, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5
# Epoch 20/25
#  - 115s - loss: 0.0646 - my_iou_metric: 0.8007 - val_loss: 0.1432 - val_my_iou_metric: 0.7909
#
# Epoch 00020: my_iou_metric did not improve from 0.80533
# Epoch 21/25
#  - 115s - loss: 0.0631 - my_iou_metric: 0.8049 - val_loss: 0.1439 - val_my_iou_metric: 0.7711
#
# Epoch 00021: my_iou_metric did not improve from 0.80533
# Epoch 22/25
#  - 115s - loss: 0.0628 - my_iou_metric: 0.8039 - val_loss: 0.1491 - val_my_iou_metric: 0.7761
#
# Epoch 00022: my_iou_metric did not improve from 0.80533
# Epoch 23/25
#  - 115s - loss: 0.0609 - my_iou_metric: 0.8031 - val_loss: 0.1396 - val_my_iou_metric: 0.7776
#
# Epoch 00023: my_iou_metric did not improve from 0.80533
# Epoch 24/25
#  - 115s - loss: 0.0628 - my_iou_metric: 0.8052 - val_loss: 0.1541 - val_my_iou_metric: 0.7796
#
# Epoch 00024: my_iou_metric did not improve from 0.80533
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/25
#  - 115s - loss: 0.0558 - my_iou_metric: 0.8159 - val_loss: 0.1432 - val_my_iou_metric: 0.7791
#
# Epoch 00025: my_iou_metric improved from 0.80533 to 0.81589, saving model to 13th-model1-100epochs-tgs-salt-20181010061020.h5

# %%
# 1st-125epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model1-125epochs-tgs-salt-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

early_stopping = EarlyStopping(monitor='my_iou_metric', mode='max', patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 25
#epochs = 200
batch_size = 32

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model1.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 115s - loss: 0.0568 - my_iou_metric: 0.8117 - val_loss: 0.1377 - val_my_iou_metric: 0.7840
#
# Epoch 00001: my_iou_metric improved from -inf to 0.81173, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 2/25
#  - 115s - loss: 0.0567 - my_iou_metric: 0.8117 - val_loss: 0.1425 - val_my_iou_metric: 0.7857
#
# Epoch 00002: my_iou_metric did not improve from 0.81173
# Epoch 3/25
#  - 115s - loss: 0.0571 - my_iou_metric: 0.8137 - val_loss: 0.1421 - val_my_iou_metric: 0.7796
#
# Epoch 00003: my_iou_metric improved from 0.81173 to 0.81366, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 4/25
#  - 115s - loss: 0.0578 - my_iou_metric: 0.8116 - val_loss: 0.1424 - val_my_iou_metric: 0.7910
#
# Epoch 00004: my_iou_metric did not improve from 0.81366
# Epoch 5/25
#  - 115s - loss: 0.0537 - my_iou_metric: 0.8142 - val_loss: 0.1390 - val_my_iou_metric: 0.7939
#
# Epoch 00005: my_iou_metric improved from 0.81366 to 0.81422, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 6/25
#  - 115s - loss: 0.0554 - my_iou_metric: 0.8127 - val_loss: 0.1533 - val_my_iou_metric: 0.7820
#
# Epoch 00006: my_iou_metric did not improve from 0.81422
# Epoch 7/25
#  - 115s - loss: 0.0540 - my_iou_metric: 0.8172 - val_loss: 0.1425 - val_my_iou_metric: 0.7961
#
# Epoch 00007: my_iou_metric improved from 0.81422 to 0.81723, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 8/25
#  - 115s - loss: 0.0540 - my_iou_metric: 0.8162 - val_loss: 0.1385 - val_my_iou_metric: 0.7935
#
# Epoch 00008: my_iou_metric did not improve from 0.81723
# Epoch 9/25
#  - 115s - loss: 0.0563 - my_iou_metric: 0.8094 - val_loss: 0.1493 - val_my_iou_metric: 0.7806
#
# Epoch 00009: my_iou_metric did not improve from 0.81723
# Epoch 10/25
#  - 115s - loss: 0.0526 - my_iou_metric: 0.8194 - val_loss: 0.1501 - val_my_iou_metric: 0.7925
#
# Epoch 00010: my_iou_metric improved from 0.81723 to 0.81941, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 11/25
#  - 114s - loss: 0.0541 - my_iou_metric: 0.8126 - val_loss: 0.1422 - val_my_iou_metric: 0.7938
#
# Epoch 00011: my_iou_metric did not improve from 0.81941
# Epoch 12/25
#  - 115s - loss: 0.0540 - my_iou_metric: 0.8183 - val_loss: 0.1349 - val_my_iou_metric: 0.7884
#
# Epoch 00012: my_iou_metric did not improve from 0.81941
# Epoch 13/25
#  - 115s - loss: 0.0552 - my_iou_metric: 0.8070 - val_loss: 0.1558 - val_my_iou_metric: 0.7867
#
# Epoch 00013: my_iou_metric did not improve from 0.81941
# Epoch 14/25
#  - 115s - loss: 0.0528 - my_iou_metric: 0.8175 - val_loss: 0.1298 - val_my_iou_metric: 0.7845
#
# Epoch 00014: my_iou_metric did not improve from 0.81941
# Epoch 15/25
#  - 115s - loss: 0.0537 - my_iou_metric: 0.8117 - val_loss: 0.1294 - val_my_iou_metric: 0.7905
#
# Epoch 00015: my_iou_metric did not improve from 0.81941
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/25
#  - 114s - loss: 0.0522 - my_iou_metric: 0.8168 - val_loss: 0.1329 - val_my_iou_metric: 0.7980
#
# Epoch 00016: my_iou_metric did not improve from 0.81941
# Epoch 17/25
#  - 115s - loss: 0.0500 - my_iou_metric: 0.8208 - val_loss: 0.1346 - val_my_iou_metric: 0.7946
#
# Epoch 00017: my_iou_metric improved from 0.81941 to 0.82084, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 18/25
#  - 115s - loss: 0.0496 - my_iou_metric: 0.8196 - val_loss: 0.1448 - val_my_iou_metric: 0.7891
#
# Epoch 00018: my_iou_metric did not improve from 0.82084
# Epoch 19/25
#  - 114s - loss: 0.0491 - my_iou_metric: 0.8172 - val_loss: 0.1478 - val_my_iou_metric: 0.7967
#
# Epoch 00019: my_iou_metric did not improve from 0.82084
# Epoch 20/25
#  - 115s - loss: 0.0497 - my_iou_metric: 0.8189 - val_loss: 0.1396 - val_my_iou_metric: 0.7886
#
# Epoch 00020: my_iou_metric did not improve from 0.82084
# Epoch 21/25
#  - 114s - loss: 0.0496 - my_iou_metric: 0.8221 - val_loss: 0.1387 - val_my_iou_metric: 0.7902
#
# Epoch 00021: my_iou_metric improved from 0.82084 to 0.82213, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 22/25
#  - 115s - loss: 0.0500 - my_iou_metric: 0.8173 - val_loss: 0.1472 - val_my_iou_metric: 0.7905
#
# Epoch 00022: my_iou_metric did not improve from 0.82213
# Epoch 23/25
#  - 115s - loss: 0.0483 - my_iou_metric: 0.8244 - val_loss: 0.1468 - val_my_iou_metric: 0.7941
#
# Epoch 00023: my_iou_metric improved from 0.82213 to 0.82441, saving model to 13th-model1-125epochs-tgs-salt-20181010071008.h5
# Epoch 24/25
#  - 115s - loss: 0.0502 - my_iou_metric: 0.8202 - val_loss: 0.1472 - val_my_iou_metric: 0.7914
#
# Epoch 00024: my_iou_metric did not improve from 0.82441
# Epoch 25/25
#  - 115s - loss: 0.0487 - my_iou_metric: 0.8214 - val_loss: 0.1479 - val_my_iou_metric: 0.7852
#
# Epoch 00025: my_iou_metric did not improve from 0.82441

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric"], label="Validation score")
ax_score.legend()

# %%
# 2nd
from google.colab import drive
drive.mount('/content/drive')
file_name =  '13th-model1-125epochs-tgs-salt-20181010071008.h5'

model1 = load_model('drive/My Drive/kaggle/{}'.format(file_name), custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
#c = optimizers.adam(lr = 0.01)
c = optimizers.Nadam(lr=0.002)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

model.summary()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 101, 101, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 101, 101, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 101, 101, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 101, 101, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 101, 101, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 101, 101, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 101, 101, 16) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 101, 101, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 101, 101, 16) 0           conv2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 101, 101, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 101, 101, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 101, 101, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 101, 101, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 101, 101, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 101, 101, 16) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 101, 101, 16) 2320        dropout_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 101, 101, 16) 0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 50, 50, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 32)   4640        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 50, 50, 32)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   9248        dropout_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 50, 50, 32)   0           conv2d_8[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 50, 50, 32)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 32)   0           conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 32)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25, 25, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 64)   18496       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 25, 25, 64)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 25, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 25, 25, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 25, 25, 64)   0           conv2d_15[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 128)  73856       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 12, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 12, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 12, 12, 128)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 128)  147584      dropout_10[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 128)  0           conv2d_18[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 12, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 12, 12, 128)  0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 128)  147584      dropout_11[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 128)  0           conv2d_20[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 128)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 6, 6, 256)    295168      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 6, 6, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 6, 6, 256)    0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 256)    590080      dropout_13[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 256)    0           conv2d_23[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 6, 6, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 6, 6, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 6, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 6, 6, 256)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 6, 6, 256)    590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 256)    0           conv2d_25[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 6, 6, 256)    1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 12, 12, 128)  295040      activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 12, 128)  295040      dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 12, 12, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 12, 12, 128)  0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 128)  147584      dropout_16[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 128)  0           conv2d_28[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 12, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 12, 12, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 128)  147584      dropout_17[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 128)  0           conv2d_30[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 25, 25, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 25, 25, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 25, 64)   73792       dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 25, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 25, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 25, 25, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 25, 25, 64)   0           activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 25, 25, 64)   36928       dropout_19[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 25, 25, 64)   0           conv2d_33[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 25, 25, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 25, 25, 64)   0           activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 25, 25, 64)   36928       dropout_20[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 25, 25, 64)   0           conv2d_35[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 50, 50, 32)   18464       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 50, 50, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 50, 50, 32)   18464       dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 50, 50, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 50, 50, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 50, 50, 32)   0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 50, 32)   9248        dropout_22[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 50, 50, 32)   0           conv2d_38[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 32)   128         add_15[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 50, 50, 32)   0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 32)   9248        dropout_23[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 50, 50, 32)   0           conv2d_40[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 32)   128         add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 101, 101, 16) 4624        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 101, 101, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 101, 101, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 101, 101, 16) 4624        dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 101, 101, 16) 64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 101, 101, 16) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 101, 101, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 101, 101, 16) 64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 101, 101, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 101, 101, 16) 0           activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 101, 101, 16) 2320        dropout_25[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 101, 101, 16) 0           conv2d_43[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 101, 101, 16) 64          add_17[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 101, 101, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 101, 101, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 101, 101, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 101, 101, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 101, 101, 16) 0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 101, 101, 16) 2320        dropout_26[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 101, 101, 16) 0           conv2d_45[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 101, 101, 16) 64          add_18[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 101, 101, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 101, 101, 1)  17          activation_45[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
#2nd 25epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model-25epochs-tgs-salt-Nadam-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')

# early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max', patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
# reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max', factor=0.5, patience=8, min_lr=0.0001, verbose=1)

epochs = 25
batch_size = 32
#epochs = 100
#batch_size = 128

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 242s - loss: -1.8494e-01 - my_iou_metric_2: 0.8152 - val_loss: 0.0929 - val_my_iou_metric_2: 0.7791
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.77913, saving model to 13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5
# Epoch 2/25
#  - 225s - loss: -2.1338e-01 - my_iou_metric_2: 0.8171 - val_loss: -2.7256e-02 - val_my_iou_metric_2: 0.7970
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.77913 to 0.79700, saving model to 13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5
# Epoch 3/25
#  - 225s - loss: -2.2646e-01 - my_iou_metric_2: 0.8205 - val_loss: -5.7726e-02 - val_my_iou_metric_2: 0.8026
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.79700 to 0.80263, saving model to 13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5
# Epoch 4/25
#  - 225s - loss: -2.3878e-01 - my_iou_metric_2: 0.8217 - val_loss: -1.0257e-01 - val_my_iou_metric_2: 0.8023
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.80263
# Epoch 5/25
#  - 225s - loss: -2.4389e-01 - my_iou_metric_2: 0.8179 - val_loss: 0.0292 - val_my_iou_metric_2: 0.7831
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.80263
# Epoch 6/25
#  - 225s - loss: -2.5518e-01 - my_iou_metric_2: 0.8219 - val_loss: -1.6664e-02 - val_my_iou_metric_2: 0.7891
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.80263
# Epoch 7/25
#  - 225s - loss: -2.6484e-01 - my_iou_metric_2: 0.8234 - val_loss: -3.2969e-03 - val_my_iou_metric_2: 0.7839
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.80263
# Epoch 8/25
#  - 226s - loss: -2.7280e-01 - my_iou_metric_2: 0.8230 - val_loss: -1.1070e-01 - val_my_iou_metric_2: 0.8056
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.80263 to 0.80563, saving model to 13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5
# Epoch 9/25
#  - 226s - loss: -2.8759e-01 - my_iou_metric_2: 0.8271 - val_loss: -9.7160e-02 - val_my_iou_metric_2: 0.8015
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 10/25
#  - 226s - loss: -2.9140e-01 - my_iou_metric_2: 0.8270 - val_loss: -8.3076e-02 - val_my_iou_metric_2: 0.7919
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 11/25
#  - 226s - loss: -2.8462e-01 - my_iou_metric_2: 0.8270 - val_loss: 0.0167 - val_my_iou_metric_2: 0.7878
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 12/25
#  - 226s - loss: -2.9561e-01 - my_iou_metric_2: 0.8268 - val_loss: -2.6825e-02 - val_my_iou_metric_2: 0.7903
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 13/25
#  - 226s - loss: -3.0674e-01 - my_iou_metric_2: 0.8320 - val_loss: -6.3305e-02 - val_my_iou_metric_2: 0.8007
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 14/25
#  - 226s - loss: -3.2499e-01 - my_iou_metric_2: 0.8340 - val_loss: -1.4338e-01 - val_my_iou_metric_2: 0.7981
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 15/25
#  - 227s - loss: -3.1650e-01 - my_iou_metric_2: 0.8312 - val_loss: -5.3162e-02 - val_my_iou_metric_2: 0.8001
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 16/25
#  - 227s - loss: -3.3230e-01 - my_iou_metric_2: 0.8337 - val_loss: 0.0627 - val_my_iou_metric_2: 0.7799
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.80563
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 17/25
#  - 227s - loss: -3.6103e-01 - my_iou_metric_2: 0.8402 - val_loss: -1.3969e-01 - val_my_iou_metric_2: 0.8139
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.80563 to 0.81388, saving model to 13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5
# Epoch 18/25
#  - 227s - loss: -3.7203e-01 - my_iou_metric_2: 0.8411 - val_loss: -8.8944e-02 - val_my_iou_metric_2: 0.7972
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 19/25
#  - 227s - loss: -3.9078e-01 - my_iou_metric_2: 0.8452 - val_loss: -1.0740e-01 - val_my_iou_metric_2: 0.8007
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 20/25
#  - 227s - loss: -3.9815e-01 - my_iou_metric_2: 0.8474 - val_loss: -1.0229e-01 - val_my_iou_metric_2: 0.8071
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 21/25
#  - 227s - loss: -4.0036e-01 - my_iou_metric_2: 0.8475 - val_loss: -1.3062e-01 - val_my_iou_metric_2: 0.8130
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 22/25
#  - 226s - loss: -3.9346e-01 - my_iou_metric_2: 0.8460 - val_loss: -1.1078e-01 - val_my_iou_metric_2: 0.8105
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 23/25
#  - 227s - loss: -3.9791e-01 - my_iou_metric_2: 0.8468 - val_loss: -1.5019e-01 - val_my_iou_metric_2: 0.8075
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 24/25
#  - 227s - loss: -4.0251e-01 - my_iou_metric_2: 0.8462 - val_loss: -1.4047e-01 - val_my_iou_metric_2: 0.8073
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.81388
# Epoch 25/25
#  - 226s - loss: -4.0559e-01 - my_iou_metric_2: 0.8495 - val_loss: -8.1434e-02 - val_my_iou_metric_2: 0.7931
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.81388
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.

# %%
#2nd 50epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model-50epochs-tgs-salt-Nadam-{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '13th-model-25epochs-tgs-salt-Nadam-20181010131009.h5'
model = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric_2': my_iou_metric_2, 'lovasz_loss': lovasz_loss})

# early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max', patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
# reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max', factor=0.5, patience=8, min_lr=0.0001, verbose=1)

epochs = 25
batch_size = 32
#epochs = 100
#batch_size = 128

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 225s - loss: -4.4235e-01 - my_iou_metric_2: 0.8559 - val_loss: -1.3020e-01 - val_my_iou_metric_2: 0.8110
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.81100, saving model to 13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5
# Epoch 2/25
#  - 209s - loss: -4.4359e-01 - my_iou_metric_2: 0.8553 - val_loss: -1.6110e-01 - val_my_iou_metric_2: 0.8116
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.81100 to 0.81162, saving model to 13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5
# Epoch 3/25
#  - 207s - loss: -4.4612e-01 - my_iou_metric_2: 0.8555 - val_loss: -1.4234e-01 - val_my_iou_metric_2: 0.8112
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.81162
# Epoch 4/25
#  - 207s - loss: -4.4954e-01 - my_iou_metric_2: 0.8575 - val_loss: -1.2371e-01 - val_my_iou_metric_2: 0.8105
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.81162
# Epoch 5/25
#  - 206s - loss: -4.4790e-01 - my_iou_metric_2: 0.8571 - val_loss: -1.1392e-01 - val_my_iou_metric_2: 0.8064
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.81162
# Epoch 6/25
#  - 207s - loss: -4.6022e-01 - my_iou_metric_2: 0.8578 - val_loss: -9.9890e-02 - val_my_iou_metric_2: 0.8088
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.81162
# Epoch 7/25
#  - 207s - loss: -4.4893e-01 - my_iou_metric_2: 0.8557 - val_loss: -1.0590e-01 - val_my_iou_metric_2: 0.8077
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.81162
# Epoch 8/25
#  - 208s - loss: -4.5887e-01 - my_iou_metric_2: 0.8576 - val_loss: -1.1456e-01 - val_my_iou_metric_2: 0.8109
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.81162
# Epoch 9/25
#  - 210s - loss: -4.6087e-01 - my_iou_metric_2: 0.8563 - val_loss: -1.1200e-01 - val_my_iou_metric_2: 0.8120
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.81162 to 0.81200, saving model to 13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5
# Epoch 10/25
#  - 209s - loss: -4.5876e-01 - my_iou_metric_2: 0.8568 - val_loss: -1.2792e-01 - val_my_iou_metric_2: 0.8105
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 11/25
#  - 210s - loss: -4.7664e-01 - my_iou_metric_2: 0.8611 - val_loss: -1.1284e-01 - val_my_iou_metric_2: 0.8074
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 12/25
#  - 210s - loss: -4.6995e-01 - my_iou_metric_2: 0.8586 - val_loss: -6.5876e-02 - val_my_iou_metric_2: 0.8079
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 13/25
#  - 209s - loss: -4.6380e-01 - my_iou_metric_2: 0.8598 - val_loss: -1.2194e-01 - val_my_iou_metric_2: 0.8070
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 14/25
#  - 208s - loss: -4.6367e-01 - my_iou_metric_2: 0.8583 - val_loss: -6.8216e-02 - val_my_iou_metric_2: 0.8000
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 15/25
#  - 208s - loss: -4.7141e-01 - my_iou_metric_2: 0.8605 - val_loss: -1.0120e-01 - val_my_iou_metric_2: 0.8042
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 16/25
#  - 209s - loss: -4.8076e-01 - my_iou_metric_2: 0.8600 - val_loss: -9.4534e-02 - val_my_iou_metric_2: 0.8049
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 17/25
#  - 210s - loss: -4.7367e-01 - my_iou_metric_2: 0.8597 - val_loss: -7.8586e-02 - val_my_iou_metric_2: 0.8075
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.81200
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 18/25
#  - 209s - loss: -4.9312e-01 - my_iou_metric_2: 0.8640 - val_loss: -1.2426e-01 - val_my_iou_metric_2: 0.8071
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.81200
# Epoch 19/25
#  - 210s - loss: -4.8351e-01 - my_iou_metric_2: 0.8626 - val_loss: -1.1639e-01 - val_my_iou_metric_2: 0.8152
#
# Epoch 00019: val_my_iou_metric_2 improved from 0.81200 to 0.81525, saving model to 13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5
# Epoch 20/25
#  - 210s - loss: -4.9810e-01 - my_iou_metric_2: 0.8642 - val_loss: -1.1376e-01 - val_my_iou_metric_2: 0.8069
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.81525
# Epoch 21/25
#  - 210s - loss: -4.9776e-01 - my_iou_metric_2: 0.8643 - val_loss: -1.1306e-01 - val_my_iou_metric_2: 0.8149
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.81525
# Epoch 22/25
#  - 210s - loss: -4.9041e-01 - my_iou_metric_2: 0.8647 - val_loss: -1.2728e-01 - val_my_iou_metric_2: 0.8136
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.81525
# Epoch 23/25
#  - 208s - loss: -5.0641e-01 - my_iou_metric_2: 0.8650 - val_loss: -1.0310e-01 - val_my_iou_metric_2: 0.8081
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.81525
# Epoch 24/25
#  - 206s - loss: -4.9824e-01 - my_iou_metric_2: 0.8638 - val_loss: -1.3056e-01 - val_my_iou_metric_2: 0.8152
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.81525
# Epoch 25/25
#  - 208s - loss: -5.0605e-01 - my_iou_metric_2: 0.8648 - val_loss: -1.3427e-01 - val_my_iou_metric_2: 0.8163
#
# Epoch 00025: val_my_iou_metric_2 improved from 0.81525 to 0.81625, saving model to 13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5

# %%
#2nd 75epochs
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
save_file = '13th-model-75-epochs-tgs-salt_{}.h5'.format(now)

from google.colab import drive
drive.mount('/content/drive')
file_name = '13th-model-50epochs-tgs-salt-Nadam-20181010211028.h5'
model = load_model('drive/My Drive/kaggle/{}'.format(file_name),
                   custom_objects={'my_iou_metric_2': my_iou_metric_2, 'lovasz_loss': lovasz_loss})

# early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max', patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_file, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
# reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max', factor=0.5, patience=8, min_lr=0.0001, verbose=1)

epochs = 25
batch_size = 32
#epochs = 100
#batch_size = 128

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=2)

model.save("drive/My Drive/kaggle/{}".format(save_file))
# Out:
# Mounted at /content/drive
# Train on 6400 samples, validate on 800 samples
# Epoch 1/25
#  - 223s - loss: -5.0271e-01 - my_iou_metric_2: 0.8647 - val_loss: -9.6515e-02 - val_my_iou_metric_2: 0.8132
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.81325, saving model to 13th-model-75-epochs-tgs-salt_20181011011023.h5
# Epoch 2/25
#  - 208s - loss: -5.0476e-01 - my_iou_metric_2: 0.8658 - val_loss: -9.5372e-02 - val_my_iou_metric_2: 0.8120
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.81325
# Epoch 3/25
#  - 208s - loss: -4.9944e-01 - my_iou_metric_2: 0.8648 - val_loss: -1.0246e-01 - val_my_iou_metric_2: 0.8105
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.81325
# Epoch 4/25
#  - 208s - loss: -5.1014e-01 - my_iou_metric_2: 0.8659 - val_loss: -8.5482e-02 - val_my_iou_metric_2: 0.8156
#
# Epoch 00004: val_my_iou_metric_2 improved from 0.81325 to 0.81563, saving model to 13th-model-75-epochs-tgs-salt_20181011011023.h5
# Epoch 5/25
#  - 207s - loss: -5.0484e-01 - my_iou_metric_2: 0.8661 - val_loss: -1.1695e-01 - val_my_iou_metric_2: 0.8171
#
# Epoch 00005: val_my_iou_metric_2 improved from 0.81563 to 0.81712, saving model to 13th-model-75-epochs-tgs-salt_20181011011023.h5
# Epoch 6/25
#  - 207s - loss: -5.0893e-01 - my_iou_metric_2: 0.8669 - val_loss: -8.0299e-02 - val_my_iou_metric_2: 0.8151
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 7/25
#  - 208s - loss: -5.1366e-01 - my_iou_metric_2: 0.8655 - val_loss: -1.1755e-01 - val_my_iou_metric_2: 0.8129
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 8/25
#  - 208s - loss: -5.1115e-01 - my_iou_metric_2: 0.8661 - val_loss: -9.2496e-02 - val_my_iou_metric_2: 0.8114
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 9/25
#  - 208s - loss: -5.0920e-01 - my_iou_metric_2: 0.8653 - val_loss: -1.4035e-01 - val_my_iou_metric_2: 0.8143
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 10/25
#  - 208s - loss: -5.0529e-01 - my_iou_metric_2: 0.8677 - val_loss: -1.1084e-01 - val_my_iou_metric_2: 0.8159
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 11/25
#  - 208s - loss: -5.1596e-01 - my_iou_metric_2: 0.8684 - val_loss: -1.0951e-01 - val_my_iou_metric_2: 0.8119
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 12/25
#  - 208s - loss: -5.1472e-01 - my_iou_metric_2: 0.8662 - val_loss: -1.0761e-01 - val_my_iou_metric_2: 0.8155
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 13/25
#  - 208s - loss: -5.1035e-01 - my_iou_metric_2: 0.8673 - val_loss: -9.7355e-02 - val_my_iou_metric_2: 0.8164
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.81712
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/25
#  - 207s - loss: -5.2210e-01 - my_iou_metric_2: 0.8686 - val_loss: -1.0988e-01 - val_my_iou_metric_2: 0.8151
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 15/25
#  - 207s - loss: -5.1720e-01 - my_iou_metric_2: 0.8685 - val_loss: -9.0252e-02 - val_my_iou_metric_2: 0.8126
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 16/25
#  - 208s - loss: -5.2858e-01 - my_iou_metric_2: 0.8698 - val_loss: -1.0788e-01 - val_my_iou_metric_2: 0.8132
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.81712
# Epoch 17/25
#  - 208s - loss: -5.2193e-01 - my_iou_metric_2: 0.8689 - val_loss: -1.0979e-01 - val_my_iou_metric_2: 0.8174
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.81712 to 0.81737, saving model to 13th-model-75-epochs-tgs-salt_20181011011023.h5
# Epoch 18/25
#  - 208s - loss: -5.3387e-01 - my_iou_metric_2: 0.8712 - val_loss: -9.9379e-02 - val_my_iou_metric_2: 0.8157
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.81737
# Epoch 19/25
#  - 208s - loss: -5.2867e-01 - my_iou_metric_2: 0.8689 - val_loss: -8.3102e-02 - val_my_iou_metric_2: 0.8126
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.81737
# Epoch 20/25
#  - 208s - loss: -5.2828e-01 - my_iou_metric_2: 0.8671 - val_loss: -9.3575e-02 - val_my_iou_metric_2: 0.8160
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.81737
# Epoch 21/25
#  - 209s - loss: -5.2824e-01 - my_iou_metric_2: 0.8693 - val_loss: -1.0109e-01 - val_my_iou_metric_2: 0.8189
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.81737 to 0.81888, saving model to 13th-model-75-epochs-tgs-salt_20181011011023.h5
# Epoch 22/25
#  - 209s - loss: -5.2484e-01 - my_iou_metric_2: 0.8695 - val_loss: -9.9132e-02 - val_my_iou_metric_2: 0.8147
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.81888
# Epoch 23/25
#  - 208s - loss: -5.2736e-01 - my_iou_metric_2: 0.8700 - val_loss: -9.5987e-02 - val_my_iou_metric_2: 0.8148
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.81888
# Epoch 24/25
#  - 208s - loss: -5.2756e-01 - my_iou_metric_2: 0.8699 - val_loss: -8.5180e-02 - val_my_iou_metric_2: 0.8119
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.81888
# Epoch 25/25
#  - 207s - loss: -5.3318e-01 - my_iou_metric_2: 0.8698 - val_loss: -9.7133e-02 - val_my_iou_metric_2: 0.8159
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.81888

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
from google.colab import drive
drive.mount('/content/drive')
model = load_model('drive/My Drive/kaggle/7-model-tgs-salt-Nadam-20181008141024.h5', custom_objects={'my_iou_metric_2': my_iou_metric_2, 'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
#preds_valid = predict_result(model1, x_valid, img_size_target)
preds_valid = predict_result(model, x_valid, img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
    #temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in thresholds])
print(ious)
# Out:
# [0.806125 0.80675  0.806    0.806375 0.808875 0.809375 0.8095   0.80975
#  0.810875 0.81125  0.811375 0.811875 0.811875 0.812125 0.811375 0.813
#  0.814    0.814625 0.8155   0.81775  0.8175   0.816375 0.816375 0.815875
#  0.81575  0.81575  0.81625  0.81625  0.816125 0.817375 0.817375]

# %%
# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("../content/test/{}.png".format(idx), grayscale = True))) / 255 for idx in test_df.index]).reshape(-1, img_size_target, img_size_target, 1)

# %%
#preds_test = predict_result(model1, x_test,img_size_target)
preds_test = predict_result(model, x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(test_df.index.values)}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")
# Out:
# Usedtime = 6.5850324630737305 s

# %%
import datetime
now = datetime.datetime.now().strftime('%Y%m%d%H%m%S')
submit_name = '14th-model-tgs-salt-submission_{}.csv'.format(now)
#submit_name = '8-model-tgs-salt-submission-Nadam_{}.csv'.format(now)


sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submit_name)

# %%
t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# Kernel run time = 1.842781286570761 hours

# %%
# !cp "../content/$submit_name" "drive/My Drive/kaggle/"
# !kaggle competitions submit -c tgs-salt-identification-challenge -f "drive/My Drive/kaggle/$submit_name" -m "$now"
# Out:
# Successfully submitted to TGS Salt Identification Challenge

# %%
# The score is 0.805, the rank is 1115
